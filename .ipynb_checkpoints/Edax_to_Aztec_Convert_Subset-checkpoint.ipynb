# %% [markdown]
# # edax_to_aztec_h5.py
# Convert EDAX .osc (orientations) + .UP2 (patterns) into an AZtec-style HDF5 (H5OINA-like) file.
#
# Usage:
#     python edax_to_aztec_h5.py --osc path/to/file.osc --up2 path/to/file.UP2 --out merged.h5
#
# Notes:
# - Designed to stream patterns to HDF5 to handle large datasets.
# - Attempts to auto-detect OSC column layout; fallback assumptions are provided.
# - For unusual EDAX variants, tweak the osc_column_map or header offsets.

# %%
import os
import h5py
import numpy as np
import struct

# %%
#PATH TO DATA
import os
os.chdir("/Volumes/T5 EVO/ExperimentSample5A/Sample5A_Step0/Grid00/Area 1")
print(os.getcwd())
# Out:
# /Volumes/T5 EVO/ExperimentSample5A/Sample5A_Step0/Grid00/Area 1
# /Volumes/T5 EVO/ExperimentSample5A/Sample5A_Step0/Grid00/Area 1

# %%
# ============================================================
# 1️⃣ Read EDAX binary OSC
# ============================================================
def read_osc_binary(filename):
    dtype = np.dtype([
        ("X", "f4"),
        ("Y", "f4"),
        ("Phi1", "f4"),
        ("PHI", "f4"),
        ("Phi2", "f4"),
        ("IQ", "f4"),
        ("CI", "f4"),
        ("Phase", "i4")
    ])
    return np.fromfile(filename, dtype=dtype)


# ============================================================
# 2️⃣ Stream UP2 patterns (memory safe)
# ============================================================
def stream_up2_patterns(path, pattern_size=(480,480)):
    h, w = pattern_size
    bytes_per_pattern = h * w
    with open(path, "rb") as f:
        f.read(1024)  # skip header
        while True:
            block = f.read(bytes_per_pattern)
            if len(block) < bytes_per_pattern:
                return
            yield np.frombuffer(block, dtype=np.uint8).reshape(h, w)


# ============================================================
# 3️⃣ Helper: get or create group safely
# ============================================================
def get_or_create_group(f, path):
    """Return group, creating parent groups if necessary"""
    if not path:  # empty string or None
        return f
    parts = path.strip("/").split("/")
    grp = f
    for p in parts:
        if p not in grp:
            grp = grp.create_group(p)
        else:
            grp = grp[p]
    return grp


# ============================================================
# 4️⃣ Safe dataset creation
# ============================================================
def safe_create_dataset(f, full_path, shape=None, dtype=None, chunks=None, data=None):
    parts = full_path.strip("/").split("/")
    if len(parts) > 1:
        parent_path = "/".join(parts[:-1])
        parent_grp = get_or_create_group(f, parent_path)
    else:
        parent_grp = f
    name = parts[-1]
    if name in parent_grp:
        if data is not None:
            parent_grp[name][:] = data
        return parent_grp[name]
    else:
        if data is not None:
            return parent_grp.create_dataset(name, data=data)
        else:
            return parent_grp.create_dataset(name, shape=shape, dtype=dtype, chunks=chunks)


# ============================================================
# 5️⃣ Copy template safely
# ============================================================
def copy_template_safe(template_path, output_path):
    with h5py.File(template_path, "r") as template, h5py.File(output_path, "w") as out:
        def copy_item(name, obj):
            if isinstance(obj, h5py.Group):
                grp = get_or_create_group(out, name)
                for k, v in obj.attrs.items():
                    grp.attrs[k] = v
            elif isinstance(obj, h5py.Dataset):
                parts = name.strip("/").split("/")
                if len(parts) > 1:
                    parent_path = "/".join(parts[:-1])
                    get_or_create_group(out, parent_path)
                out.create_dataset(name, shape=obj.shape, dtype=obj.dtype, chunks=obj.chunks)
                for k, v in obj.attrs.items():
                    out[name].attrs[k] = v
        template.visititems(copy_item)
    print("Template structure copied safely to", output_path)


# ============================================================
# 6️⃣ Fill new H5OINA with OSC + patterns
# ============================================================
def fill_h5oina(output_path, osc_data, patterns_gen, pattern_size=(480,480)):
    N = len(osc_data)
    Ny, Nx = pattern_size
    with h5py.File(output_path, "r+") as f:
        # ScanData
        safe_create_dataset(f, "ScanData/EulerAngles", data=np.column_stack([osc_data["Phi1"], osc_data["PHI"], osc_data["Phi2"]]))
        safe_create_dataset(f, "ScanData/Coordinates", data=np.column_stack([osc_data["X"], osc_data["Y"]]))
        safe_create_dataset(f, "ScanData/Phase", data=osc_data["Phase"].astype(np.int32))
        safe_create_dataset(f, "ScanData/BC", data=osc_data["IQ"])
        safe_create_dataset(f, "ScanData/BS", data=osc_data["CI"])
        safe_create_dataset(f, "ScanData/Index", data=np.arange(N, dtype=np.int32))
        safe_create_dataset(f, "ScanData/Bands", data=np.zeros(N))
        safe_create_dataset(f, "ScanData/MAD", data=np.zeros(N))

        # PatternData
        dset = safe_create_dataset(
            f, "PatternData/Patterns",
            shape=(N, Ny, Nx),
            dtype=np.uint8,
            chunks=(1, Ny, Nx)
        )

        print("Streaming patterns into H5OINA...")
        for i, pat in enumerate(patterns_gen):
            if i >= N:
                break
            dset[i] = pat
            if (i+1) % 200 == 0:
                print(f"  {i+1}/{N} patterns written")
    print("H5OINA file successfully written.")


# ============================================================
# 7️⃣ Run full pipeline
# ============================================================
osc_path = "S5A_Grid00_Step0.osc"
up2_path = "S5A_Grid00_Step0.UP2"
template_h5 = "Si_indent.h5oina"
output_h5 = "converted_from_template.h5oina"

# Load OSC
osc_data = read_osc_binary(osc_path)

# Stream patterns (memory safe)
patterns_gen = stream_up2_patterns(up2_path, pattern_size=(480,480))

# Copy template structure safely
copy_template_safe(template_h5, output_h5)

# Fill new H5OINA with your data
fill_h5oina(output_h5, osc_data, patterns_gen, pattern_size=(480,480))

print("Conversion complete! Ready for AZtecCrystal.")
# Out:
# Template structure copied safely to converted_from_template.h5oina
# Streaming patterns into H5OINA...
#   200/455309 patterns written
#   400/455309 patterns written
#   600/455309 patterns written
#   800/455309 patterns written
#   1000/455309 patterns written
#   1200/455309 patterns written
#   1400/455309 patterns written
#   1600/455309 patterns written
#   1800/455309 patterns written
#   2000/455309 patterns written
#   2200/455309 patterns written
#   2400/455309 patterns written
#   2600/455309 patterns written
#   2800/455309 patterns written
#   3000/455309 patterns written
#   3200/455309 patterns written
#   3400/455309 patterns written
#   3600/455309 patterns written
#   3800/455309 patterns written
#   4000/455309 patterns written
#   4200/455309 patterns written
#   4400/455309 patterns written
#   4600/455309 patterns written
#   4800/455309 patterns written
#   5000/455309 patterns written
#   5200/455309 patterns written
#   5400/455309 patterns written
#   5600/455309 patterns written
#   5800/455309 patterns written
#   6000/455309 patterns written
#   6200/455309 patterns written
#   6400/455309 patterns written
#   6600/455309 patterns written
#   6800/455309 patterns written
#   7000/455309 patterns written
#   7200/455309 patterns written
#   7400/455309 patterns written
#   7600/455309 patterns written
#   7800/455309 patterns written
#   8000/455309 patterns written
#   8200/455309 patterns written
#   8400/455309 patterns written
#   8600/455309 patterns written
#   8800/455309 patterns written
#   9000/455309 patterns written
#   9200/455309 patterns written
#   9400/455309 patterns written
#   9600/455309 patterns written
#   9800/455309 patterns written
#   10000/455309 patterns written
#   10200/455309 patterns written
#   10400/455309 patterns written
#   10600/455309 patterns written
#   10800/455309 patterns written
#   11000/455309 patterns written
#   11200/455309 patterns written
#   11400/455309 patterns written
#   11600/455309 patterns written
#   11800/455309 patterns written
#   12000/455309 patterns written
#   12200/455309 patterns written
#   12400/455309 patterns written
#   12600/455309 patterns written
#   12800/455309 patterns written
#   13000/455309 patterns written
#   13200/455309 patterns written
#   13400/455309 patterns written
#   13600/455309 patterns written
#   13800/455309 patterns written
#   14000/455309 patterns written
#   14200/455309 patterns written
#   14400/455309 patterns written
#   14600/455309 patterns written
#   14800/455309 patterns written
#   15000/455309 patterns written
#   15200/455309 patterns written
#   15400/455309 patterns written
#   15600/455309 patterns written
#   15800/455309 patterns written
#   16000/455309 patterns written
#   16200/455309 patterns written
#   16400/455309 patterns written
#   16600/455309 patterns written
#   16800/455309 patterns written
#   17000/455309 patterns written
#   17200/455309 patterns written
#   17400/455309 patterns written
#   17600/455309 patterns written
#   17800/455309 patterns written
#   18000/455309 patterns written
#   18200/455309 patterns written
#   18400/455309 patterns written
#   18600/455309 patterns written
#   18800/455309 patterns written
#   19000/455309 patterns written
#   19200/455309 patterns written
#   19400/455309 patterns written
#   19600/455309 patterns written
#   19800/455309 patterns written
#   20000/455309 patterns written
#   20200/455309 patterns written
#   20400/455309 patterns written
#   20600/455309 patterns written
#   20800/455309 patterns written
#   21000/455309 patterns written
#   21200/455309 patterns written
#   21400/455309 patterns written
#   21600/455309 patterns written
#   21800/455309 patterns written
#   22000/455309 patterns written
#   22200/455309 patterns written
#   22400/455309 patterns written
#   22600/455309 patterns written
#   22800/455309 patterns written
#   23000/455309 patterns written
#   23200/455309 patterns written
#   23400/455309 patterns written
#   23600/455309 patterns written
#   23800/455309 patterns written
#   24000/455309 patterns written
#   24200/455309 patterns written
#   24400/455309 patterns written
#   24600/455309 patterns written
#   24800/455309 patterns written
#   25000/455309 patterns written
#   25200/455309 patterns written
#   25400/455309 patterns written
#   25600/455309 patterns written
#   25800/455309 patterns written
#   26000/455309 patterns written
#   26200/455309 patterns written
#   26400/455309 patterns written
#   26600/455309 patterns written
#   26800/455309 patterns written
#   27000/455309 patterns written
#   27200/455309 patterns written
#   27400/455309 patterns written
#   27600/455309 patterns written
#   27800/455309 patterns written
#   28000/455309 patterns written
#   28200/455309 patterns written
#   28400/455309 patterns written
#   28600/455309 patterns written
#   28800/455309 patterns written
#   29000/455309 patterns written
#   29200/455309 patterns written
#   29400/455309 patterns written
#   29600/455309 patterns written
#   29800/455309 patterns written
#   30000/455309 patterns written
#   30200/455309 patterns written
#   30400/455309 patterns written
#   30600/455309 patterns written
#   30800/455309 patterns written
#   31000/455309 patterns written
#   31200/455309 patterns written
#   31400/455309 patterns written
#   31600/455309 patterns written
#   31800/455309 patterns written
#   32000/455309 patterns written
#   32200/455309 patterns written
#   32400/455309 patterns written
#   32600/455309 patterns written
#   32800/455309 patterns written
#   33000/455309 patterns written
#   33200/455309 patterns written
#   33400/455309 patterns written
#   33600/455309 patterns written
#   33800/455309 patterns written
#   34000/455309 patterns written
#   34200/455309 patterns written
#   34400/455309 patterns written
#   34600/455309 patterns written
#   34800/455309 patterns written
#   35000/455309 patterns written
#   35200/455309 patterns written
#   35400/455309 patterns written
#   35600/455309 patterns written
#   35800/455309 patterns written
#   36000/455309 patterns written
#   36200/455309 patterns written
#   36400/455309 patterns written
#   36600/455309 patterns written
#   36800/455309 patterns written
#   37000/455309 patterns written
#   37200/455309 patterns written
#   37400/455309 patterns written
#   37600/455309 patterns written
#   37800/455309 patterns written
#   38000/455309 patterns written
#   38200/455309 patterns written
#   38400/455309 patterns written
#   38600/455309 patterns written
#   38800/455309 patterns written
#   39000/455309 patterns written
#   39200/455309 patterns written
#   39400/455309 patterns written
#   39600/455309 patterns written
#   39800/455309 patterns written
#   40000/455309 patterns written
#   40200/455309 patterns written
#   40400/455309 patterns written
#   40600/455309 patterns written
#   40800/455309 patterns written
#   41000/455309 patterns written
#   41200/455309 patterns written
#   41400/455309 patterns written
#   41600/455309 patterns written
#   41800/455309 patterns written
#   42000/455309 patterns written
#   42200/455309 patterns written
#   42400/455309 patterns written
#   42600/455309 patterns written
#   42800/455309 patterns written
#   43000/455309 patterns written
#   43200/455309 patterns written
#   43400/455309 patterns written
#   43600/455309 patterns written
#   43800/455309 patterns written
#   44000/455309 patterns written
#   44200/455309 patterns written
#   44400/455309 patterns written
#   44600/455309 patterns written
#   44800/455309 patterns written
#   45000/455309 patterns written
#   45200/455309 patterns written
#   45400/455309 patterns written
#   45600/455309 patterns written
#   45800/455309 patterns written
#   46000/455309 patterns written
#   46200/455309 patterns written
#   46400/455309 patterns written
#   46600/455309 patterns written
#   46800/455309 patterns written
#   47000/455309 patterns written
#   47200/455309 patterns written
#   47400/455309 patterns written
#   47600/455309 patterns written
#   47800/455309 patterns written
#   48000/455309 patterns written
#   48200/455309 patterns written
#   48400/455309 patterns written
#   48600/455309 patterns written
#   48800/455309 patterns written
#   49000/455309 patterns written
#   49200/455309 patterns written
#   49400/455309 patterns written
#   49600/455309 patterns written
#   49800/455309 patterns written
#   50000/455309 patterns written
#   50200/455309 patterns written
#   50400/455309 patterns written
#   50600/455309 patterns written
#   50800/455309 patterns written
#   51000/455309 patterns written
#   51200/455309 patterns written
#   51400/455309 patterns written
#   51600/455309 patterns written
#   51800/455309 patterns written
#   52000/455309 patterns written
#   52200/455309 patterns written
#   52400/455309 patterns written
#   52600/455309 patterns written
#   52800/455309 patterns written
#   53000/455309 patterns written
#   53200/455309 patterns written
#   53400/455309 patterns written
#   53600/455309 patterns written
#   53800/455309 patterns written
#   54000/455309 patterns written
#   54200/455309 patterns written
#   54400/455309 patterns written
#   54600/455309 patterns written
#   54800/455309 patterns written
#   55000/455309 patterns written
#   55200/455309 patterns written
#   55400/455309 patterns written
#   55600/455309 patterns written
#   55800/455309 patterns written
#   56000/455309 patterns written
#   56200/455309 patterns written
#   56400/455309 patterns written
#   56600/455309 patterns written
#   56800/455309 patterns written
#   57000/455309 patterns written
#   57200/455309 patterns written
#   57400/455309 patterns written
#   57600/455309 patterns written
#   57800/455309 patterns written
#   58000/455309 patterns written
#   58200/455309 patterns written
#   58400/455309 patterns written
#   58600/455309 patterns written
#   58800/455309 patterns written
#   59000/455309 patterns written
#   59200/455309 patterns written
#   59400/455309 patterns written
#   59600/455309 patterns written
#   59800/455309 patterns written
#   60000/455309 patterns written
#   60200/455309 patterns written
#   60400/455309 patterns written
#   60600/455309 patterns written
#   60800/455309 patterns written
#   61000/455309 patterns written
#   61200/455309 patterns written
#   61400/455309 patterns written
#   61600/455309 patterns written
#   61800/455309 patterns written
#   62000/455309 patterns written
#   62200/455309 patterns written
#   62400/455309 patterns written
#   62600/455309 patterns written
#   62800/455309 patterns written
#   63000/455309 patterns written
#   63200/455309 patterns written
#   63400/455309 patterns written
#   63600/455309 patterns written
#   63800/455309 patterns written
#   64000/455309 patterns written
#   64200/455309 patterns written
#   64400/455309 patterns written
#   64600/455309 patterns written
#   64800/455309 patterns written
#   65000/455309 patterns written
#   65200/455309 patterns written
#   65400/455309 patterns written
#   65600/455309 patterns written
#   65800/455309 patterns written
#   66000/455309 patterns written
#   66200/455309 patterns written
#   66400/455309 patterns written
#   66600/455309 patterns written
#   66800/455309 patterns written
#   67000/455309 patterns written
#   67200/455309 patterns written
#   67400/455309 patterns written
#   67600/455309 patterns written
#   67800/455309 patterns written
#   68000/455309 patterns written
#   68200/455309 patterns written
#   68400/455309 patterns written
#   68600/455309 patterns written
#   68800/455309 patterns written
#   69000/455309 patterns written
#   69200/455309 patterns written
#   69400/455309 patterns written
#   69600/455309 patterns written
#   69800/455309 patterns written
#   70000/455309 patterns written
#   70200/455309 patterns written
#   70400/455309 patterns written
#   70600/455309 patterns written
#   70800/455309 patterns written
#   71000/455309 patterns written
#   71200/455309 patterns written
#   71400/455309 patterns written
#   71600/455309 patterns written
#   71800/455309 patterns written
#   72000/455309 patterns written
#   72200/455309 patterns written
#   72400/455309 patterns written
#   72600/455309 patterns written
#   72800/455309 patterns written
#   73000/455309 patterns written
#   73200/455309 patterns written
#   73400/455309 patterns written
#   73600/455309 patterns written
#   73800/455309 patterns written
#   74000/455309 patterns written
#   74200/455309 patterns written
#   74400/455309 patterns written
#   74600/455309 patterns written
#   74800/455309 patterns written
#   75000/455309 patterns written
#   75200/455309 patterns written
#   75400/455309 patterns written
#   75600/455309 patterns written
#   75800/455309 patterns written
#   76000/455309 patterns written
#   76200/455309 patterns written
#   76400/455309 patterns written
#   76600/455309 patterns written
#   76800/455309 patterns written
#   77000/455309 patterns written
#   77200/455309 patterns written
#   77400/455309 patterns written
#   77600/455309 patterns written
#   77800/455309 patterns written
#   78000/455309 patterns written
#   78200/455309 patterns written
#   78400/455309 patterns written
#   78600/455309 patterns written
#   78800/455309 patterns written
#   79000/455309 patterns written
#   79200/455309 patterns written
#   79400/455309 patterns written
#   79600/455309 patterns written
#   79800/455309 patterns written
#   80000/455309 patterns written
#   80200/455309 patterns written
#   80400/455309 patterns written
#   80600/455309 patterns written
#   80800/455309 patterns written
#   81000/455309 patterns written
#   81200/455309 patterns written
#   81400/455309 patterns written
#   81600/455309 patterns written
#   81800/455309 patterns written
#   82000/455309 patterns written
#   82200/455309 patterns written
#   82400/455309 patterns written
#   82600/455309 patterns written
#   82800/455309 patterns written
#   83000/455309 patterns written
#   83200/455309 patterns written
#   83400/455309 patterns written
#   83600/455309 patterns written
#   83800/455309 patterns written
#   84000/455309 patterns written
#   84200/455309 patterns written
#   84400/455309 patterns written
#   84600/455309 patterns written
#   84800/455309 patterns written
#   85000/455309 patterns written
#   85200/455309 patterns written
#   85400/455309 patterns written
#   85600/455309 patterns written
#   85800/455309 patterns written
#   86000/455309 patterns written
#   86200/455309 patterns written
#   86400/455309 patterns written
#   86600/455309 patterns written
#   86800/455309 patterns written
#   87000/455309 patterns written
#   87200/455309 patterns written
#   87400/455309 patterns written
#   87600/455309 patterns written
#   87800/455309 patterns written
#   88000/455309 patterns written
#   88200/455309 patterns written
#   88400/455309 patterns written
#   88600/455309 patterns written
#   88800/455309 patterns written
#   89000/455309 patterns written
#   89200/455309 patterns written
#   89400/455309 patterns written
#   89600/455309 patterns written
#   89800/455309 patterns written
#   90000/455309 patterns written
#   90200/455309 patterns written
#   90400/455309 patterns written
#   90600/455309 patterns written
#   90800/455309 patterns written
#   91000/455309 patterns written
#   91200/455309 patterns written
#   91400/455309 patterns written
#   91600/455309 patterns written
#   91800/455309 patterns written
#   92000/455309 patterns written
#   92200/455309 patterns written
#   92400/455309 patterns written
#   92600/455309 patterns written
#   92800/455309 patterns written
#   93000/455309 patterns written
#   93200/455309 patterns written
#   93400/455309 patterns written
#   93600/455309 patterns written
#   93800/455309 patterns written
#   94000/455309 patterns written
#   94200/455309 patterns written
#   94400/455309 patterns written
#   94600/455309 patterns written
#   94800/455309 patterns written
#   95000/455309 patterns written
#   95200/455309 patterns written
#   95400/455309 patterns written
#   95600/455309 patterns written
#   95800/455309 patterns written
#   96000/455309 patterns written
#   96200/455309 patterns written
#   96400/455309 patterns written
#   96600/455309 patterns written
#   96800/455309 patterns written
#   97000/455309 patterns written
#   97200/455309 patterns written
#   97400/455309 patterns written
#   97600/455309 patterns written
#   97800/455309 patterns written
#   98000/455309 patterns written
#   98200/455309 patterns written
#   98400/455309 patterns written
#   98600/455309 patterns written
#   98800/455309 patterns written
#   99000/455309 patterns written
#   99200/455309 patterns written
#   99400/455309 patterns written
#   99600/455309 patterns written
#   99800/455309 patterns written
#   100000/455309 patterns written
#   100200/455309 patterns written
#   100400/455309 patterns written
#   100600/455309 patterns written
#   100800/455309 patterns written
#   101000/455309 patterns written
#   101200/455309 patterns written
#   101400/455309 patterns written
#   101600/455309 patterns written
#   101800/455309 patterns written
#   102000/455309 patterns written
#   102200/455309 patterns written
#   102400/455309 patterns written
#   102600/455309 patterns written
#   102800/455309 patterns written
#   103000/455309 patterns written
#   103200/455309 patterns written
#   103400/455309 patterns written
#   103600/455309 patterns written
#   103800/455309 patterns written
#   104000/455309 patterns written
#   104200/455309 patterns written
#   104400/455309 patterns written
#   104600/455309 patterns written
#   104800/455309 patterns written
#   105000/455309 patterns written
#   105200/455309 patterns written
#   105400/455309 patterns written
#   105600/455309 patterns written
#   105800/455309 patterns written
#   106000/455309 patterns written
#   106200/455309 patterns written
#   106400/455309 patterns written
#   106600/455309 patterns written
#   106800/455309 patterns written
#   107000/455309 patterns written
#   107200/455309 patterns written
#   107400/455309 patterns written
#   107600/455309 patterns written
#   107800/455309 patterns written
#   108000/455309 patterns written
#   108200/455309 patterns written
#   108400/455309 patterns written
#   108600/455309 patterns written
#   108800/455309 patterns written
#   109000/455309 patterns written
#   109200/455309 patterns written
#   109400/455309 patterns written
#   109600/455309 patterns written
#   109800/455309 patterns written
#   110000/455309 patterns written
#   110200/455309 patterns written
#   110400/455309 patterns written
#   110600/455309 patterns written
#   110800/455309 patterns written
#   111000/455309 patterns written
#   111200/455309 patterns written
#   111400/455309 patterns written
#   111600/455309 patterns written
#   111800/455309 patterns written
#   112000/455309 patterns written
#   112200/455309 patterns written
#   112400/455309 patterns written
#   112600/455309 patterns written
#   112800/455309 patterns written
#   113000/455309 patterns written
#   113200/455309 patterns written
#   113400/455309 patterns written
#   113600/455309 patterns written
#   113800/455309 patterns written
#   114000/455309 patterns written
#   114200/455309 patterns written
#   114400/455309 patterns written
#   114600/455309 patterns written
#   114800/455309 patterns written
#   115000/455309 patterns written
#   115200/455309 patterns written
#   115400/455309 patterns written
#   115600/455309 patterns written
#   115800/455309 patterns written
#   116000/455309 patterns written
#   116200/455309 patterns written
#   116400/455309 patterns written
#   116600/455309 patterns written
#   116800/455309 patterns written
#   117000/455309 patterns written
#   117200/455309 patterns written
#   117400/455309 patterns written
#   117600/455309 patterns written
#   117800/455309 patterns written
#   118000/455309 patterns written
#   118200/455309 patterns written
#   118400/455309 patterns written
#   118600/455309 patterns written
#   118800/455309 patterns written
#   119000/455309 patterns written
#   119200/455309 patterns written
#   119400/455309 patterns written
#   119600/455309 patterns written
#   119800/455309 patterns written
#   120000/455309 patterns written
#   120200/455309 patterns written
#   120400/455309 patterns written
#   120600/455309 patterns written
#   120800/455309 patterns written
#   121000/455309 patterns written
#   121200/455309 patterns written
#   121400/455309 patterns written
#   121600/455309 patterns written
#   121800/455309 patterns written
#   122000/455309 patterns written
#   122200/455309 patterns written
#   122400/455309 patterns written
#   122600/455309 patterns written
#   122800/455309 patterns written
#   123000/455309 patterns written
#   123200/455309 patterns written
#   123400/455309 patterns written
#   123600/455309 patterns written
#   123800/455309 patterns written
#   124000/455309 patterns written
#   124200/455309 patterns written
#   124400/455309 patterns written
#   124600/455309 patterns written
#   124800/455309 patterns written
#   125000/455309 patterns written
#   125200/455309 patterns written
#   125400/455309 patterns written
#   125600/455309 patterns written
#   125800/455309 patterns written
#   126000/455309 patterns written
#   126200/455309 patterns written
#   126400/455309 patterns written
#   126600/455309 patterns written
#   126800/455309 patterns written
#   127000/455309 patterns written
#   127200/455309 patterns written
#   127400/455309 patterns written
#   127600/455309 patterns written
#   127800/455309 patterns written
#   128000/455309 patterns written
#   128200/455309 patterns written
#   128400/455309 patterns written
#   128600/455309 patterns written
#   128800/455309 patterns written
#   129000/455309 patterns written
#   129200/455309 patterns written
#   129400/455309 patterns written
#   129600/455309 patterns written
#   129800/455309 patterns written
#   130000/455309 patterns written
#   130200/455309 patterns written
#   130400/455309 patterns written
#   130600/455309 patterns written
#   130800/455309 patterns written
#   131000/455309 patterns written
#   131200/455309 patterns written
#   131400/455309 patterns written
#   131600/455309 patterns written
#   131800/455309 patterns written
#   132000/455309 patterns written
#   132200/455309 patterns written
#   132400/455309 patterns written
#   132600/455309 patterns written
#   132800/455309 patterns written
#   133000/455309 patterns written
#   133200/455309 patterns written
#   133400/455309 patterns written
#   133600/455309 patterns written
#   133800/455309 patterns written
#   134000/455309 patterns written
#   134200/455309 patterns written
#   134400/455309 patterns written
#   134600/455309 patterns written
#   134800/455309 patterns written
#   135000/455309 patterns written
#   135200/455309 patterns written
#   135400/455309 patterns written
#   135600/455309 patterns written
#   135800/455309 patterns written
#   136000/455309 patterns written
#   136200/455309 patterns written
#   136400/455309 patterns written
#   136600/455309 patterns written
#   136800/455309 patterns written
#   137000/455309 patterns written
#   137200/455309 patterns written
#   137400/455309 patterns written
#   137600/455309 patterns written
#   137800/455309 patterns written
#   138000/455309 patterns written
#   138200/455309 patterns written
#   138400/455309 patterns written
#   138600/455309 patterns written
#   138800/455309 patterns written
#   139000/455309 patterns written
#   139200/455309 patterns written
#   139400/455309 patterns written
#   139600/455309 patterns written
#   139800/455309 patterns written
#   140000/455309 patterns written
#   140200/455309 patterns written
#   140400/455309 patterns written
#   140600/455309 patterns written
#   140800/455309 patterns written
#   141000/455309 patterns written
#   141200/455309 patterns written
#   141400/455309 patterns written
#   141600/455309 patterns written
#   141800/455309 patterns written
#   142000/455309 patterns written
#   142200/455309 patterns written
#   142400/455309 patterns written
#   142600/455309 patterns written
#   142800/455309 patterns written
#   143000/455309 patterns written
#   143200/455309 patterns written
#   143400/455309 patterns written
#   143600/455309 patterns written
#   143800/455309 patterns written
#   144000/455309 patterns written
#   144200/455309 patterns written
#   144400/455309 patterns written
#   144600/455309 patterns written
#   144800/455309 patterns written
#   145000/455309 patterns written
#   145200/455309 patterns written
#   145400/455309 patterns written
#   145600/455309 patterns written
#   145800/455309 patterns written
#   146000/455309 patterns written
#   146200/455309 patterns written
#   146400/455309 patterns written
#   146600/455309 patterns written
#   146800/455309 patterns written
#   147000/455309 patterns written
#   147200/455309 patterns written
#   147400/455309 patterns written
#   147600/455309 patterns written
#   147800/455309 patterns written
#   148000/455309 patterns written
#   148200/455309 patterns written
#   148400/455309 patterns written
#   148600/455309 patterns written
#   148800/455309 patterns written
#   149000/455309 patterns written
#   149200/455309 patterns written
#   149400/455309 patterns written
# H5OINA file successfully written.
# Conversion complete! Ready for AZtecCrystal.

# %%
# User paths
osc_path = "S5A_Grid00_Step0.osc"
up2_path = "S5A_Grid00_Step0.UP2"
template_h5 = "Si_indent.h5oina"
output_h5 = "converted_from_template.h5oina"
