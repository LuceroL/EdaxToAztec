# %% [markdown]
# # edax_to_aztec_h5.py
# Convert EDAX .osc (orientations) + .UP2 (patterns) into an AZtec-style HDF5 (H5OINA-like) file.
#
# Usage:
#     python edax_to_aztec_h5.py --osc path/to/file.osc --up2 path/to/file.UP2 --out merged.h5
#
# Notes:
# - Designed to stream patterns to HDF5 to handle large datasets.
# - Attempts to auto-detect OSC column layout; fallback assumptions are provided.
# - For unusual EDAX variants, tweak the osc_column_map or header offsets.

# %%
import os
import h5py
import numpy as np
import struct

# %%
#PATH TO DATA
# %cd /Volumes/T7/UP2/Grid6
# Out:
# /Volumes/T7/UP2/Grid6

# %%
# ------------------------------------------------------------
# 1. Read EDAX OSC metadata (binary or text-safe)
# ------------------------------------------------------------
def read_osc_binary(filename):
    """
    Reads EDAX binary OSC format (32 bytes per point):
    float32 X, Y, Phi1, PHI, Phi2, IQ, CI
    int32 Phase
    """
    record_dtype = np.dtype([
        ("X", "f4"),
        ("Y", "f4"),
        ("Phi1", "f4"),
        ("PHI", "f4"),
        ("Phi2", "f4"),
        ("IQ", "f4"),
        ("CI", "f4"),
        ("Phase", "i4"),
    ])

    print("Reading BINARY OSC:", filename)
    data = np.fromfile(filename, dtype=record_dtype)
    print(f" -> Loaded {len(data)} points")

    return {
        "X": data["X"],
        "Y": data["Y"],
        "Euler": np.column_stack([data["Phi1"], data["PHI"], data["Phi2"]]),
        "IQ": data["IQ"],
        "CI": data["CI"],
        "Phase": data["Phase"]
    }

# ------------------------------------------------------------
# 2. Stream .UP2 patterns (memory-safe)
# ------------------------------------------------------------
def read_up2_patterns(path, pattern_size=(480, 480)):
    """
    Reads EDAX .UP2 patterns one by one without loading entire file.
    pattern_size: (height, width) in pixels
    """
    h, w = pattern_size
    bytes_per_pattern = h * w  # uint8 per pixel

    with open(path, "rb") as f:
        header = f.read(1024)  # skip EDAX header
        count = 0
        while True:
            chunk = f.read(bytes_per_pattern)
            if len(chunk) < bytes_per_pattern:
                break
            yield np.frombuffer(chunk, dtype=np.uint8).reshape(h, w)
            count += 1
            if count % 50 == 0:
                print(f" → Loaded {count} patterns...")

# ------------------------------------------------------------
# 3. Write HDF5 (Aztec-style, streaming)
# ------------------------------------------------------------
def convert_to_h5(osc_file, up2_file, output_file, pattern_size=(480,480)):
    osc = read_osc_binary(osc_file)

    with h5py.File(output_file, "w") as h5:
        # EBSD metadata
        meta_grp = h5.create_group("ScanMetadata")
        meta_grp.attrs["NumPoints"] = len(osc["X"])
        meta_grp.attrs["Format"] = "H5OINA"
        meta_grp.attrs["Creator"] = "EDAX → Aztec Converter (Python)"

        # Euler and position data
        data_grp = h5.create_group("Data")
        data_grp.create_dataset("EulerAngles", data=osc["Euler"])
        data_grp.create_dataset("X", data=osc["X"])
        data_grp.create_dataset("Y", data=osc["Y"])
        data_grp.create_dataset("IQ", data=osc["IQ"])
        data_grp.create_dataset("CI", data=osc["CI"])
        data_grp.create_dataset("PhaseId", data=osc["Phase"])

        # Patterns (streaming)
        pat_grp = h5.create_group("Patterns")
        dset = pat_grp.create_dataset(
            "images",
            shape=(0, pattern_size[0], pattern_size[1]),
            maxshape=(None, pattern_size[0], pattern_size[1]),
            dtype=np.uint8,
            chunks=(1, pattern_size[0], pattern_size[1])
        )

        print("Reading patterns and writing to HDF5...")
        count = 0
        for pat in read_up2_patterns(up2_file, pattern_size):
            dset.resize(count + 1, axis=0)
            dset[count] = pat
            count += 1

        print(f"Done! Total patterns: {count}")
        print("Saved HDF5 →", output_file)

# ------------------------------------------------------------
# 4. Example Usage in Jupyter
# ------------------------------------------------------------
osc_file = "S3A_Grid6_Step4.osc"
up2_file = "S3A_Grid6_step4.up2"
output_h5 = "S3A_Grid6_Step4_merged_aztec.h5"

convert_to_h5(osc_file, up2_file, output_h5, pattern_size=(480, 480))
# Out:
# Reading BINARY OSC: S3A_Grid6_Step4.osc
#  -> Loaded 422927 points
# Reading patterns and writing to HDF5...
#  → Loaded 50 patterns...
#  → Loaded 100 patterns...
#  → Loaded 150 patterns...
#  → Loaded 200 patterns...
#  → Loaded 250 patterns...
#  → Loaded 300 patterns...
#  → Loaded 350 patterns...
#  → Loaded 400 patterns...
#  → Loaded 450 patterns...
#  → Loaded 500 patterns...
#  → Loaded 550 patterns...
#  → Loaded 600 patterns...
#  → Loaded 650 patterns...
#  → Loaded 700 patterns...
#  → Loaded 750 patterns...
#  → Loaded 800 patterns...
#  → Loaded 850 patterns...
#  → Loaded 900 patterns...
#  → Loaded 950 patterns...
#  → Loaded 1000 patterns...
#  → Loaded 1050 patterns...
#  → Loaded 1100 patterns...
#  → Loaded 1150 patterns...
#  → Loaded 1200 patterns...
#  → Loaded 1250 patterns...
#  → Loaded 1300 patterns...
#  → Loaded 1350 patterns...
#  → Loaded 1400 patterns...
#  → Loaded 1450 patterns...
#  → Loaded 1500 patterns...
#  → Loaded 1550 patterns...
#  → Loaded 1600 patterns...
#  → Loaded 1650 patterns...
#  → Loaded 1700 patterns...
#  → Loaded 1750 patterns...
#  → Loaded 1800 patterns...
#  → Loaded 1850 patterns...
#  → Loaded 1900 patterns...
#  → Loaded 1950 patterns...
#  → Loaded 2000 patterns...
#  → Loaded 2050 patterns...
#  → Loaded 2100 patterns...
#  → Loaded 2150 patterns...
#  → Loaded 2200 patterns...
#  → Loaded 2250 patterns...
#  → Loaded 2300 patterns...
#  → Loaded 2350 patterns...
#  → Loaded 2400 patterns...
#  → Loaded 2450 patterns...
#  → Loaded 2500 patterns...
#  → Loaded 2550 patterns...
#  → Loaded 2600 patterns...
#  → Loaded 2650 patterns...
#  → Loaded 2700 patterns...
#  → Loaded 2750 patterns...
#  → Loaded 2800 patterns...
#  → Loaded 2850 patterns...
#  → Loaded 2900 patterns...
#  → Loaded 2950 patterns...
#  → Loaded 3000 patterns...
#  → Loaded 3050 patterns...
#  → Loaded 3100 patterns...
#  → Loaded 3150 patterns...
#  → Loaded 3200 patterns...
#  → Loaded 3250 patterns...
#  → Loaded 3300 patterns...
#  → Loaded 3350 patterns...
#  → Loaded 3400 patterns...
#  → Loaded 3450 patterns...
#  → Loaded 3500 patterns...
#  → Loaded 3550 patterns...
#  → Loaded 3600 patterns...
#  → Loaded 3650 patterns...
#  → Loaded 3700 patterns...
#  → Loaded 3750 patterns...
#  → Loaded 3800 patterns...
#  → Loaded 3850 patterns...
#  → Loaded 3900 patterns...
#  → Loaded 3950 patterns...
#  → Loaded 4000 patterns...
#  → Loaded 4050 patterns...
#  → Loaded 4100 patterns...
#  → Loaded 4150 patterns...
#  → Loaded 4200 patterns...
#  → Loaded 4250 patterns...
#  → Loaded 4300 patterns...
#  → Loaded 4350 patterns...
#  → Loaded 4400 patterns...
#  → Loaded 4450 patterns...
#  → Loaded 4500 patterns...
#  → Loaded 4550 patterns...
#  → Loaded 4600 patterns...
#  → Loaded 4650 patterns...
#  → Loaded 4700 patterns...
#  → Loaded 4750 patterns...
#  → Loaded 4800 patterns...
#  → Loaded 4850 patterns...
#  → Loaded 4900 patterns...
#  → Loaded 4950 patterns...
#  → Loaded 5000 patterns...
#  → Loaded 5050 patterns...
#  → Loaded 5100 patterns...
#  → Loaded 5150 patterns...
#  → Loaded 5200 patterns...
#  → Loaded 5250 patterns...
#  → Loaded 5300 patterns...
#  → Loaded 5350 patterns...
#  → Loaded 5400 patterns...
#  → Loaded 5450 patterns...
#  → Loaded 5500 patterns...
#  → Loaded 5550 patterns...
#  → Loaded 5600 patterns...
#  → Loaded 5650 patterns...
#  → Loaded 5700 patterns...
#  → Loaded 5750 patterns...
#  → Loaded 5800 patterns...
#  → Loaded 5850 patterns...
#  → Loaded 5900 patterns...
#  → Loaded 5950 patterns...
#  → Loaded 6000 patterns...
#  → Loaded 6050 patterns...
#  → Loaded 6100 patterns...
#  → Loaded 6150 patterns...
#  → Loaded 6200 patterns...
#  → Loaded 6250 patterns...
#  → Loaded 6300 patterns...
#  → Loaded 6350 patterns...
#  → Loaded 6400 patterns...
#  → Loaded 6450 patterns...
#  → Loaded 6500 patterns...
#  → Loaded 6550 patterns...
#  → Loaded 6600 patterns...
#  → Loaded 6650 patterns...
#  → Loaded 6700 patterns...
#  → Loaded 6750 patterns...
#  → Loaded 6800 patterns...
#  → Loaded 6850 patterns...
#  → Loaded 6900 patterns...
#  → Loaded 6950 patterns...
#  → Loaded 7000 patterns...
#  → Loaded 7050 patterns...
#  → Loaded 7100 patterns...
#  → Loaded 7150 patterns...
#  → Loaded 7200 patterns...
#  → Loaded 7250 patterns...
#  → Loaded 7300 patterns...
#  → Loaded 7350 patterns...
#  → Loaded 7400 patterns...
#  → Loaded 7450 patterns...
#  → Loaded 7500 patterns...
#  → Loaded 7550 patterns...
#  → Loaded 7600 patterns...
#  → Loaded 7650 patterns...
#  → Loaded 7700 patterns...
#  → Loaded 7750 patterns...
#  → Loaded 7800 patterns...
#  → Loaded 7850 patterns...
#  → Loaded 7900 patterns...
#  → Loaded 7950 patterns...
#  → Loaded 8000 patterns...
#  → Loaded 8050 patterns...
#  → Loaded 8100 patterns...
#  → Loaded 8150 patterns...
#  → Loaded 8200 patterns...
#  → Loaded 8250 patterns...
#  → Loaded 8300 patterns...
#  → Loaded 8350 patterns...
#  → Loaded 8400 patterns...
#  → Loaded 8450 patterns...
#  → Loaded 8500 patterns...
#  → Loaded 8550 patterns...
#  → Loaded 8600 patterns...
#  → Loaded 8650 patterns...
#  → Loaded 8700 patterns...
#  → Loaded 8750 patterns...
#  → Loaded 8800 patterns...
#  → Loaded 8850 patterns...
#  → Loaded 8900 patterns...
#  → Loaded 8950 patterns...
#  → Loaded 9000 patterns...
#  → Loaded 9050 patterns...
#  → Loaded 9100 patterns...
#  → Loaded 9150 patterns...
#  → Loaded 9200 patterns...
#  → Loaded 9250 patterns...
#  → Loaded 9300 patterns...
#  → Loaded 9350 patterns...
#  → Loaded 9400 patterns...
#  → Loaded 9450 patterns...
#  → Loaded 9500 patterns...
#  → Loaded 9550 patterns...
#  → Loaded 9600 patterns...
#  → Loaded 9650 patterns...
#  → Loaded 9700 patterns...
#  → Loaded 9750 patterns...
#  → Loaded 9800 patterns...
#  → Loaded 9850 patterns...
#  → Loaded 9900 patterns...
#  → Loaded 9950 patterns...
#  → Loaded 10000 patterns...
#  → Loaded 10050 patterns...
#  → Loaded 10100 patterns...
#  → Loaded 10150 patterns...
#  → Loaded 10200 patterns...
#  → Loaded 10250 patterns...
#  → Loaded 10300 patterns...
#  → Loaded 10350 patterns...
#  → Loaded 10400 patterns...
#  → Loaded 10450 patterns...
#  → Loaded 10500 patterns...
#  → Loaded 10550 patterns...
#  → Loaded 10600 patterns...
#  → Loaded 10650 patterns...
#  → Loaded 10700 patterns...
#  → Loaded 10750 patterns...
#  → Loaded 10800 patterns...
#  → Loaded 10850 patterns...
#  → Loaded 10900 patterns...
#  → Loaded 10950 patterns...
#  → Loaded 11000 patterns...
#  → Loaded 11050 patterns...
#  → Loaded 11100 patterns...
#  → Loaded 11150 patterns...
#  → Loaded 11200 patterns...
#  → Loaded 11250 patterns...
#  → Loaded 11300 patterns...
#  → Loaded 11350 patterns...
#  → Loaded 11400 patterns...
#  → Loaded 11450 patterns...
#  → Loaded 11500 patterns...
#  → Loaded 11550 patterns...
#  → Loaded 11600 patterns...
#  → Loaded 11650 patterns...
#  → Loaded 11700 patterns...
#  → Loaded 11750 patterns...
#  → Loaded 11800 patterns...
#  → Loaded 11850 patterns...
#  → Loaded 11900 patterns...
#  → Loaded 11950 patterns...
#  → Loaded 12000 patterns...
#  → Loaded 12050 patterns...
#  → Loaded 12100 patterns...
#  → Loaded 12150 patterns...
#  → Loaded 12200 patterns...
#  → Loaded 12250 patterns...
#  → Loaded 12300 patterns...
#  → Loaded 12350 patterns...
#  → Loaded 12400 patterns...
#  → Loaded 12450 patterns...
#  → Loaded 12500 patterns...
#  → Loaded 12550 patterns...
#  → Loaded 12600 patterns...
#  → Loaded 12650 patterns...
#  → Loaded 12700 patterns...
#  → Loaded 12750 patterns...
#  → Loaded 12800 patterns...
#  → Loaded 12850 patterns...
#  → Loaded 12900 patterns...
#  → Loaded 12950 patterns...
#  → Loaded 13000 patterns...
#  → Loaded 13050 patterns...
#  → Loaded 13100 patterns...
#  → Loaded 13150 patterns...
#  → Loaded 13200 patterns...
#  → Loaded 13250 patterns...
#  → Loaded 13300 patterns...
#  → Loaded 13350 patterns...
#  → Loaded 13400 patterns...
#  → Loaded 13450 patterns...
#  → Loaded 13500 patterns...
#  → Loaded 13550 patterns...
#  → Loaded 13600 patterns...
#  → Loaded 13650 patterns...
#  → Loaded 13700 patterns...
#  → Loaded 13750 patterns...
#  → Loaded 13800 patterns...
#  → Loaded 13850 patterns...
#  → Loaded 13900 patterns...
#  → Loaded 13950 patterns...
#  → Loaded 14000 patterns...
#  → Loaded 14050 patterns...
#  → Loaded 14100 patterns...
#  → Loaded 14150 patterns...
#  → Loaded 14200 patterns...
#  → Loaded 14250 patterns...
#  → Loaded 14300 patterns...
#  → Loaded 14350 patterns...
#  → Loaded 14400 patterns...
#  → Loaded 14450 patterns...
#  → Loaded 14500 patterns...
#  → Loaded 14550 patterns...
#  → Loaded 14600 patterns...
#  → Loaded 14650 patterns...
#  → Loaded 14700 patterns...
#  → Loaded 14750 patterns...
#  → Loaded 14800 patterns...
#  → Loaded 14850 patterns...
#  → Loaded 14900 patterns...
#  → Loaded 14950 patterns...
#  → Loaded 15000 patterns...
#  → Loaded 15050 patterns...
#  → Loaded 15100 patterns...
#  → Loaded 15150 patterns...
#  → Loaded 15200 patterns...
#  → Loaded 15250 patterns...
#  → Loaded 15300 patterns...
#  → Loaded 15350 patterns...
#  → Loaded 15400 patterns...
#  → Loaded 15450 patterns...
#  → Loaded 15500 patterns...
#  → Loaded 15550 patterns...
#  → Loaded 15600 patterns...
#  → Loaded 15650 patterns...
#  → Loaded 15700 patterns...
#  → Loaded 15750 patterns...
#  → Loaded 15800 patterns...
#  → Loaded 15850 patterns...
#  → Loaded 15900 patterns...
#  → Loaded 15950 patterns...
#  → Loaded 16000 patterns...
#  → Loaded 16050 patterns...
#  → Loaded 16100 patterns...
#  → Loaded 16150 patterns...
#  → Loaded 16200 patterns...
#  → Loaded 16250 patterns...
#  → Loaded 16300 patterns...
#  → Loaded 16350 patterns...
#  → Loaded 16400 patterns...
#  → Loaded 16450 patterns...
#  → Loaded 16500 patterns...
#  → Loaded 16550 patterns...
#  → Loaded 16600 patterns...
#  → Loaded 16650 patterns...
#  → Loaded 16700 patterns...
#  → Loaded 16750 patterns...
#  → Loaded 16800 patterns...
#  → Loaded 16850 patterns...
#  → Loaded 16900 patterns...
#  → Loaded 16950 patterns...
#  → Loaded 17000 patterns...
#  → Loaded 17050 patterns...
#  → Loaded 17100 patterns...
#  → Loaded 17150 patterns...
#  → Loaded 17200 patterns...
#  → Loaded 17250 patterns...
#  → Loaded 17300 patterns...
#  → Loaded 17350 patterns...
#  → Loaded 17400 patterns...
#  → Loaded 17450 patterns...
#  → Loaded 17500 patterns...
#  → Loaded 17550 patterns...
#  → Loaded 17600 patterns...
#  → Loaded 17650 patterns...
#  → Loaded 17700 patterns...
#  → Loaded 17750 patterns...
#  → Loaded 17800 patterns...
#  → Loaded 17850 patterns...
#  → Loaded 17900 patterns...
#  → Loaded 17950 patterns...
#  → Loaded 18000 patterns...
#  → Loaded 18050 patterns...
#  → Loaded 18100 patterns...
#  → Loaded 18150 patterns...
#  → Loaded 18200 patterns...
#  → Loaded 18250 patterns...
#  → Loaded 18300 patterns...
#  → Loaded 18350 patterns...
#  → Loaded 18400 patterns...
#  → Loaded 18450 patterns...
#  → Loaded 18500 patterns...
#  → Loaded 18550 patterns...
#  → Loaded 18600 patterns...
#  → Loaded 18650 patterns...
#  → Loaded 18700 patterns...
#  → Loaded 18750 patterns...
#  → Loaded 18800 patterns...
#  → Loaded 18850 patterns...
#  → Loaded 18900 patterns...
#  → Loaded 18950 patterns...
#  → Loaded 19000 patterns...
#  → Loaded 19050 patterns...
#  → Loaded 19100 patterns...
#  → Loaded 19150 patterns...
#  → Loaded 19200 patterns...
#  → Loaded 19250 patterns...
#  → Loaded 19300 patterns...
#  → Loaded 19350 patterns...
#  → Loaded 19400 patterns...
#  → Loaded 19450 patterns...
#  → Loaded 19500 patterns...
#  → Loaded 19550 patterns...
#  → Loaded 19600 patterns...
#  → Loaded 19650 patterns...
#  → Loaded 19700 patterns...
#  → Loaded 19750 patterns...
#  → Loaded 19800 patterns...
#  → Loaded 19850 patterns...
#  → Loaded 19900 patterns...
#  → Loaded 19950 patterns...
#  → Loaded 20000 patterns...
#  → Loaded 20050 patterns...
#  → Loaded 20100 patterns...
#  → Loaded 20150 patterns...
#  → Loaded 20200 patterns...
#  → Loaded 20250 patterns...
#  → Loaded 20300 patterns...
#  → Loaded 20350 patterns...
#  → Loaded 20400 patterns...
#  → Loaded 20450 patterns...
#  → Loaded 20500 patterns...
#  → Loaded 20550 patterns...
#  → Loaded 20600 patterns...
#  → Loaded 20650 patterns...
#  → Loaded 20700 patterns...
#  → Loaded 20750 patterns...
#  → Loaded 20800 patterns...
#  → Loaded 20850 patterns...
#  → Loaded 20900 patterns...
#  → Loaded 20950 patterns...
#  → Loaded 21000 patterns...
#  → Loaded 21050 patterns...
#  → Loaded 21100 patterns...
#  → Loaded 21150 patterns...
#  → Loaded 21200 patterns...
#  → Loaded 21250 patterns...
#  → Loaded 21300 patterns...
#  → Loaded 21350 patterns...
#  → Loaded 21400 patterns...
#  → Loaded 21450 patterns...
#  → Loaded 21500 patterns...
#  → Loaded 21550 patterns...
#  → Loaded 21600 patterns...
#  → Loaded 21650 patterns...
#  → Loaded 21700 patterns...
#  → Loaded 21750 patterns...
#  → Loaded 21800 patterns...
#  → Loaded 21850 patterns...
#  → Loaded 21900 patterns...
#  → Loaded 21950 patterns...
#  → Loaded 22000 patterns...
#  → Loaded 22050 patterns...
#  → Loaded 22100 patterns...
#  → Loaded 22150 patterns...
#  → Loaded 22200 patterns...
#  → Loaded 22250 patterns...
#  → Loaded 22300 patterns...
#  → Loaded 22350 patterns...
#  → Loaded 22400 patterns...
#  → Loaded 22450 patterns...
#  → Loaded 22500 patterns...
#  → Loaded 22550 patterns...
#  → Loaded 22600 patterns...
#  → Loaded 22650 patterns...
#  → Loaded 22700 patterns...
#  → Loaded 22750 patterns...
#  → Loaded 22800 patterns...
#  → Loaded 22850 patterns...
#  → Loaded 22900 patterns...
#  → Loaded 22950 patterns...
#  → Loaded 23000 patterns...
#  → Loaded 23050 patterns...
#  → Loaded 23100 patterns...
#  → Loaded 23150 patterns...
#  → Loaded 23200 patterns...
#  → Loaded 23250 patterns...
#  → Loaded 23300 patterns...
#  → Loaded 23350 patterns...
#  → Loaded 23400 patterns...
#  → Loaded 23450 patterns...
#  → Loaded 23500 patterns...
#  → Loaded 23550 patterns...
#  → Loaded 23600 patterns...
#  → Loaded 23650 patterns...
#  → Loaded 23700 patterns...
#  → Loaded 23750 patterns...
#  → Loaded 23800 patterns...
#  → Loaded 23850 patterns...
#  → Loaded 23900 patterns...
#  → Loaded 23950 patterns...
#  → Loaded 24000 patterns...
#  → Loaded 24050 patterns...
#  → Loaded 24100 patterns...
#  → Loaded 24150 patterns...
#  → Loaded 24200 patterns...
#  → Loaded 24250 patterns...
#  → Loaded 24300 patterns...
#  → Loaded 24350 patterns...
#  → Loaded 24400 patterns...
#  → Loaded 24450 patterns...
#  → Loaded 24500 patterns...
#  → Loaded 24550 patterns...
#  → Loaded 24600 patterns...
#  → Loaded 24650 patterns...
#  → Loaded 24700 patterns...
#  → Loaded 24750 patterns...
#  → Loaded 24800 patterns...
#  → Loaded 24850 patterns...
#  → Loaded 24900 patterns...
#  → Loaded 24950 patterns...
#  → Loaded 25000 patterns...
#  → Loaded 25050 patterns...
#  → Loaded 25100 patterns...
#  → Loaded 25150 patterns...
#  → Loaded 25200 patterns...
#  → Loaded 25250 patterns...
#  → Loaded 25300 patterns...
#  → Loaded 25350 patterns...
#  → Loaded 25400 patterns...
#  → Loaded 25450 patterns...
#  → Loaded 25500 patterns...
#  → Loaded 25550 patterns...
#  → Loaded 25600 patterns...
#  → Loaded 25650 patterns...
#  → Loaded 25700 patterns...
#  → Loaded 25750 patterns...
#  → Loaded 25800 patterns...
#  → Loaded 25850 patterns...
#  → Loaded 25900 patterns...
#  → Loaded 25950 patterns...
#  → Loaded 26000 patterns...
#  → Loaded 26050 patterns...
#  → Loaded 26100 patterns...
#  → Loaded 26150 patterns...
#  → Loaded 26200 patterns...
#  → Loaded 26250 patterns...
#  → Loaded 26300 patterns...
#  → Loaded 26350 patterns...
#  → Loaded 26400 patterns...
#  → Loaded 26450 patterns...
#  → Loaded 26500 patterns...
#  → Loaded 26550 patterns...
#  → Loaded 26600 patterns...
#  → Loaded 26650 patterns...
#  → Loaded 26700 patterns...
#  → Loaded 26750 patterns...
#  → Loaded 26800 patterns...
#  → Loaded 26850 patterns...
#  → Loaded 26900 patterns...
#  → Loaded 26950 patterns...
#  → Loaded 27000 patterns...
#  → Loaded 27050 patterns...
#  → Loaded 27100 patterns...
#  → Loaded 27150 patterns...
#  → Loaded 27200 patterns...
#  → Loaded 27250 patterns...
#  → Loaded 27300 patterns...
#  → Loaded 27350 patterns...
#  → Loaded 27400 patterns...
#  → Loaded 27450 patterns...
#  → Loaded 27500 patterns...
#  → Loaded 27550 patterns...
#  → Loaded 27600 patterns...
#  → Loaded 27650 patterns...
#  → Loaded 27700 patterns...
#  → Loaded 27750 patterns...
#  → Loaded 27800 patterns...
#  → Loaded 27850 patterns...
#  → Loaded 27900 patterns...
#  → Loaded 27950 patterns...
#  → Loaded 28000 patterns...
#  → Loaded 28050 patterns...
#  → Loaded 28100 patterns...
#  → Loaded 28150 patterns...
#  → Loaded 28200 patterns...
#  → Loaded 28250 patterns...
#  → Loaded 28300 patterns...
#  → Loaded 28350 patterns...
#  → Loaded 28400 patterns...
#  → Loaded 28450 patterns...
#  → Loaded 28500 patterns...
#  → Loaded 28550 patterns...
#  → Loaded 28600 patterns...
#  → Loaded 28650 patterns...
#  → Loaded 28700 patterns...
#  → Loaded 28750 patterns...
#  → Loaded 28800 patterns...
#  → Loaded 28850 patterns...
#  → Loaded 28900 patterns...
#  → Loaded 28950 patterns...
#  → Loaded 29000 patterns...
#  → Loaded 29050 patterns...
#  → Loaded 29100 patterns...
#  → Loaded 29150 patterns...
#  → Loaded 29200 patterns...
#  → Loaded 29250 patterns...
#  → Loaded 29300 patterns...
#  → Loaded 29350 patterns...
#  → Loaded 29400 patterns...
#  → Loaded 29450 patterns...
#  → Loaded 29500 patterns...
#  → Loaded 29550 patterns...
#  → Loaded 29600 patterns...
#  → Loaded 29650 patterns...
#  → Loaded 29700 patterns...
#  → Loaded 29750 patterns...
#  → Loaded 29800 patterns...
#  → Loaded 29850 patterns...
#  → Loaded 29900 patterns...
#  → Loaded 29950 patterns...
#  → Loaded 30000 patterns...
#  → Loaded 30050 patterns...
#  → Loaded 30100 patterns...
#  → Loaded 30150 patterns...
#  → Loaded 30200 patterns...
#  → Loaded 30250 patterns...
#  → Loaded 30300 patterns...
#  → Loaded 30350 patterns...
#  → Loaded 30400 patterns...
#  → Loaded 30450 patterns...
#  → Loaded 30500 patterns...
#  → Loaded 30550 patterns...
#  → Loaded 30600 patterns...
#  → Loaded 30650 patterns...
#  → Loaded 30700 patterns...
#  → Loaded 30750 patterns...
#  → Loaded 30800 patterns...
#  → Loaded 30850 patterns...
#  → Loaded 30900 patterns...
#  → Loaded 30950 patterns...
#  → Loaded 31000 patterns...
#  → Loaded 31050 patterns...
#  → Loaded 31100 patterns...
#  → Loaded 31150 patterns...
#  → Loaded 31200 patterns...
#  → Loaded 31250 patterns...
#  → Loaded 31300 patterns...
#  → Loaded 31350 patterns...
#  → Loaded 31400 patterns...
#  → Loaded 31450 patterns...
#  → Loaded 31500 patterns...
#  → Loaded 31550 patterns...
#  → Loaded 31600 patterns...
#  → Loaded 31650 patterns...
#  → Loaded 31700 patterns...
#  → Loaded 31750 patterns...
#  → Loaded 31800 patterns...
#  → Loaded 31850 patterns...
#  → Loaded 31900 patterns...
#  → Loaded 31950 patterns...
#  → Loaded 32000 patterns...
#  → Loaded 32050 patterns...
#  → Loaded 32100 patterns...
#  → Loaded 32150 patterns...
#  → Loaded 32200 patterns...
#  → Loaded 32250 patterns...
#  → Loaded 32300 patterns...
#  → Loaded 32350 patterns...
#  → Loaded 32400 patterns...
#  → Loaded 32450 patterns...
#  → Loaded 32500 patterns...
#  → Loaded 32550 patterns...
#  → Loaded 32600 patterns...
#  → Loaded 32650 patterns...
#  → Loaded 32700 patterns...
#  → Loaded 32750 patterns...
#  → Loaded 32800 patterns...
#  → Loaded 32850 patterns...
#  → Loaded 32900 patterns...
#  → Loaded 32950 patterns...
#  → Loaded 33000 patterns...
#  → Loaded 33050 patterns...
#  → Loaded 33100 patterns...
#  → Loaded 33150 patterns...
#  → Loaded 33200 patterns...
#  → Loaded 33250 patterns...
#  → Loaded 33300 patterns...
#  → Loaded 33350 patterns...
#  → Loaded 33400 patterns...
#  → Loaded 33450 patterns...
#  → Loaded 33500 patterns...
#  → Loaded 33550 patterns...
#  → Loaded 33600 patterns...
#  → Loaded 33650 patterns...
#  → Loaded 33700 patterns...
#  → Loaded 33750 patterns...
#  → Loaded 33800 patterns...
#  → Loaded 33850 patterns...
#  → Loaded 33900 patterns...
#  → Loaded 33950 patterns...
#  → Loaded 34000 patterns...
#  → Loaded 34050 patterns...
#  → Loaded 34100 patterns...
#  → Loaded 34150 patterns...
#  → Loaded 34200 patterns...
#  → Loaded 34250 patterns...
#  → Loaded 34300 patterns...
#  → Loaded 34350 patterns...
#  → Loaded 34400 patterns...
#  → Loaded 34450 patterns...
#  → Loaded 34500 patterns...
#  → Loaded 34550 patterns...
#  → Loaded 34600 patterns...
#  → Loaded 34650 patterns...
#  → Loaded 34700 patterns...
#  → Loaded 34750 patterns...
#  → Loaded 34800 patterns...
#  → Loaded 34850 patterns...
#  → Loaded 34900 patterns...
#  → Loaded 34950 patterns...
#  → Loaded 35000 patterns...
#  → Loaded 35050 patterns...
#  → Loaded 35100 patterns...
#  → Loaded 35150 patterns...
#  → Loaded 35200 patterns...
#  → Loaded 35250 patterns...
#  → Loaded 35300 patterns...
#  → Loaded 35350 patterns...
#  → Loaded 35400 patterns...
#  → Loaded 35450 patterns...
#  → Loaded 35500 patterns...
#  → Loaded 35550 patterns...
#  → Loaded 35600 patterns...
#  → Loaded 35650 patterns...
#  → Loaded 35700 patterns...
#  → Loaded 35750 patterns...
#  → Loaded 35800 patterns...
#  → Loaded 35850 patterns...
#  → Loaded 35900 patterns...
#  → Loaded 35950 patterns...
#  → Loaded 36000 patterns...
#  → Loaded 36050 patterns...
#  → Loaded 36100 patterns...
#  → Loaded 36150 patterns...
#  → Loaded 36200 patterns...
#  → Loaded 36250 patterns...
#  → Loaded 36300 patterns...
#  → Loaded 36350 patterns...
#  → Loaded 36400 patterns...
#  → Loaded 36450 patterns...
#  → Loaded 36500 patterns...
#  → Loaded 36550 patterns...
#  → Loaded 36600 patterns...
#  → Loaded 36650 patterns...
#  → Loaded 36700 patterns...
#  → Loaded 36750 patterns...
#  → Loaded 36800 patterns...
#  → Loaded 36850 patterns...
#  → Loaded 36900 patterns...
#  → Loaded 36950 patterns...
#  → Loaded 37000 patterns...
#  → Loaded 37050 patterns...
#  → Loaded 37100 patterns...
#  → Loaded 37150 patterns...
#  → Loaded 37200 patterns...
#  → Loaded 37250 patterns...
#  → Loaded 37300 patterns...
#  → Loaded 37350 patterns...
#  → Loaded 37400 patterns...
#  → Loaded 37450 patterns...
#  → Loaded 37500 patterns...
#  → Loaded 37550 patterns...
#  → Loaded 37600 patterns...
#  → Loaded 37650 patterns...
#  → Loaded 37700 patterns...
#  → Loaded 37750 patterns...
#  → Loaded 37800 patterns...
#  → Loaded 37850 patterns...
#  → Loaded 37900 patterns...
#  → Loaded 37950 patterns...
#  → Loaded 38000 patterns...
#  → Loaded 38050 patterns...
#  → Loaded 38100 patterns...
#  → Loaded 38150 patterns...
#  → Loaded 38200 patterns...
#  → Loaded 38250 patterns...
#  → Loaded 38300 patterns...
#  → Loaded 38350 patterns...
#  → Loaded 38400 patterns...
#  → Loaded 38450 patterns...
#  → Loaded 38500 patterns...
#  → Loaded 38550 patterns...
#  → Loaded 38600 patterns...
#  → Loaded 38650 patterns...
#  → Loaded 38700 patterns...
#  → Loaded 38750 patterns...
#  → Loaded 38800 patterns...
#  → Loaded 38850 patterns...
#  → Loaded 38900 patterns...
#  → Loaded 38950 patterns...
#  → Loaded 39000 patterns...
#  → Loaded 39050 patterns...
#  → Loaded 39100 patterns...
#  → Loaded 39150 patterns...
#  → Loaded 39200 patterns...
#  → Loaded 39250 patterns...
#  → Loaded 39300 patterns...
#  → Loaded 39350 patterns...
#  → Loaded 39400 patterns...
#  → Loaded 39450 patterns...
#  → Loaded 39500 patterns...
#  → Loaded 39550 patterns...
#  → Loaded 39600 patterns...
#  → Loaded 39650 patterns...
#  → Loaded 39700 patterns...
#  → Loaded 39750 patterns...
#  → Loaded 39800 patterns...
#  → Loaded 39850 patterns...
#  → Loaded 39900 patterns...
#  → Loaded 39950 patterns...
#  → Loaded 40000 patterns...
#  → Loaded 40050 patterns...
#  → Loaded 40100 patterns...
#  → Loaded 40150 patterns...
#  → Loaded 40200 patterns...
#  → Loaded 40250 patterns...
#  → Loaded 40300 patterns...
#  → Loaded 40350 patterns...
#  → Loaded 40400 patterns...
#  → Loaded 40450 patterns...
#  → Loaded 40500 patterns...
#  → Loaded 40550 patterns...
#  → Loaded 40600 patterns...
#  → Loaded 40650 patterns...
#  → Loaded 40700 patterns...
#  → Loaded 40750 patterns...
#  → Loaded 40800 patterns...
#  → Loaded 40850 patterns...
#  → Loaded 40900 patterns...
#  → Loaded 40950 patterns...
#  → Loaded 41000 patterns...
#  → Loaded 41050 patterns...
#  → Loaded 41100 patterns...
#  → Loaded 41150 patterns...
#  → Loaded 41200 patterns...
#  → Loaded 41250 patterns...
#  → Loaded 41300 patterns...
#  → Loaded 41350 patterns...
#  → Loaded 41400 patterns...
#  → Loaded 41450 patterns...
#  → Loaded 41500 patterns...
#  → Loaded 41550 patterns...
#  → Loaded 41600 patterns...
#  → Loaded 41650 patterns...
#  → Loaded 41700 patterns...
#  → Loaded 41750 patterns...
#  → Loaded 41800 patterns...
#  → Loaded 41850 patterns...
#  → Loaded 41900 patterns...
#  → Loaded 41950 patterns...
#  → Loaded 42000 patterns...
#  → Loaded 42050 patterns...
#  → Loaded 42100 patterns...
#  → Loaded 42150 patterns...
#  → Loaded 42200 patterns...
#  → Loaded 42250 patterns...
#  → Loaded 42300 patterns...
#  → Loaded 42350 patterns...
#  → Loaded 42400 patterns...
#  → Loaded 42450 patterns...
#  → Loaded 42500 patterns...
#  → Loaded 42550 patterns...
#  → Loaded 42600 patterns...
#  → Loaded 42650 patterns...
#  → Loaded 42700 patterns...
#  → Loaded 42750 patterns...
#  → Loaded 42800 patterns...
#  → Loaded 42850 patterns...
#  → Loaded 42900 patterns...
#  → Loaded 42950 patterns...
#  → Loaded 43000 patterns...
#  → Loaded 43050 patterns...
#  → Loaded 43100 patterns...
#  → Loaded 43150 patterns...
#  → Loaded 43200 patterns...
#  → Loaded 43250 patterns...
#  → Loaded 43300 patterns...
#  → Loaded 43350 patterns...
#  → Loaded 43400 patterns...
#  → Loaded 43450 patterns...
#  → Loaded 43500 patterns...
#  → Loaded 43550 patterns...
#  → Loaded 43600 patterns...
#  → Loaded 43650 patterns...
#  → Loaded 43700 patterns...
#  → Loaded 43750 patterns...
#  → Loaded 43800 patterns...
#  → Loaded 43850 patterns...
#  → Loaded 43900 patterns...
#  → Loaded 43950 patterns...
#  → Loaded 44000 patterns...
#  → Loaded 44050 patterns...
#  → Loaded 44100 patterns...
#  → Loaded 44150 patterns...
#  → Loaded 44200 patterns...
#  → Loaded 44250 patterns...
#  → Loaded 44300 patterns...
#  → Loaded 44350 patterns...
#  → Loaded 44400 patterns...
#  → Loaded 44450 patterns...
#  → Loaded 44500 patterns...
#  → Loaded 44550 patterns...
#  → Loaded 44600 patterns...
#  → Loaded 44650 patterns...
#  → Loaded 44700 patterns...
#  → Loaded 44750 patterns...
#  → Loaded 44800 patterns...
#  → Loaded 44850 patterns...
#  → Loaded 44900 patterns...
#  → Loaded 44950 patterns...
#  → Loaded 45000 patterns...
#  → Loaded 45050 patterns...
#  → Loaded 45100 patterns...
#  → Loaded 45150 patterns...
#  → Loaded 45200 patterns...
#  → Loaded 45250 patterns...
#  → Loaded 45300 patterns...
#  → Loaded 45350 patterns...
#  → Loaded 45400 patterns...
#  → Loaded 45450 patterns...
#  → Loaded 45500 patterns...
#  → Loaded 45550 patterns...
#  → Loaded 45600 patterns...
#  → Loaded 45650 patterns...
#  → Loaded 45700 patterns...
#  → Loaded 45750 patterns...
#  → Loaded 45800 patterns...
#  → Loaded 45850 patterns...
#  → Loaded 45900 patterns...
#  → Loaded 45950 patterns...
#  → Loaded 46000 patterns...
#  → Loaded 46050 patterns...
#  → Loaded 46100 patterns...
#  → Loaded 46150 patterns...
#  → Loaded 46200 patterns...
#  → Loaded 46250 patterns...
#  → Loaded 46300 patterns...
#  → Loaded 46350 patterns...
#  → Loaded 46400 patterns...
#  → Loaded 46450 patterns...
#  → Loaded 46500 patterns...
#  → Loaded 46550 patterns...
#  → Loaded 46600 patterns...
#  → Loaded 46650 patterns...
#  → Loaded 46700 patterns...
#  → Loaded 46750 patterns...
#  → Loaded 46800 patterns...
#  → Loaded 46850 patterns...
#  → Loaded 46900 patterns...
#  → Loaded 46950 patterns...
#  → Loaded 47000 patterns...
#  → Loaded 47050 patterns...
#  → Loaded 47100 patterns...
#  → Loaded 47150 patterns...
#  → Loaded 47200 patterns...
#  → Loaded 47250 patterns...
#  → Loaded 47300 patterns...
#  → Loaded 47350 patterns...
#  → Loaded 47400 patterns...
#  → Loaded 47450 patterns...
#  → Loaded 47500 patterns...
#  → Loaded 47550 patterns...
#  → Loaded 47600 patterns...
#  → Loaded 47650 patterns...
#  → Loaded 47700 patterns...
#  → Loaded 47750 patterns...
#  → Loaded 47800 patterns...
#  → Loaded 47850 patterns...
#  → Loaded 47900 patterns...
#  → Loaded 47950 patterns...
#  → Loaded 48000 patterns...
#  → Loaded 48050 patterns...
#  → Loaded 48100 patterns...
#  → Loaded 48150 patterns...
#  → Loaded 48200 patterns...
#  → Loaded 48250 patterns...
#  → Loaded 48300 patterns...
#  → Loaded 48350 patterns...
#  → Loaded 48400 patterns...
#  → Loaded 48450 patterns...
#  → Loaded 48500 patterns...
#  → Loaded 48550 patterns...
#  → Loaded 48600 patterns...
#  → Loaded 48650 patterns...
#  → Loaded 48700 patterns...
#  → Loaded 48750 patterns...
#  → Loaded 48800 patterns...
#  → Loaded 48850 patterns...
#  → Loaded 48900 patterns...
#  → Loaded 48950 patterns...
#  → Loaded 49000 patterns...
#  → Loaded 49050 patterns...
#  → Loaded 49100 patterns...
#  → Loaded 49150 patterns...
#  → Loaded 49200 patterns...
#  → Loaded 49250 patterns...
#  → Loaded 49300 patterns...
#  → Loaded 49350 patterns...
#  → Loaded 49400 patterns...
#  → Loaded 49450 patterns...
#  → Loaded 49500 patterns...
#  → Loaded 49550 patterns...
#  → Loaded 49600 patterns...
#  → Loaded 49650 patterns...
#  → Loaded 49700 patterns...
#  → Loaded 49750 patterns...
#  → Loaded 49800 patterns...
#  → Loaded 49850 patterns...
#  → Loaded 49900 patterns...
#  → Loaded 49950 patterns...
#  → Loaded 50000 patterns...
#  → Loaded 50050 patterns...
#  → Loaded 50100 patterns...
#  → Loaded 50150 patterns...
#  → Loaded 50200 patterns...
#  → Loaded 50250 patterns...
#  → Loaded 50300 patterns...
#  → Loaded 50350 patterns...
#  → Loaded 50400 patterns...
#  → Loaded 50450 patterns...
#  → Loaded 50500 patterns...
#  → Loaded 50550 patterns...
#  → Loaded 50600 patterns...
#  → Loaded 50650 patterns...
#  → Loaded 50700 patterns...
#  → Loaded 50750 patterns...
#  → Loaded 50800 patterns...
#  → Loaded 50850 patterns...
#  → Loaded 50900 patterns...
#  → Loaded 50950 patterns...
#  → Loaded 51000 patterns...
#  → Loaded 51050 patterns...
#  → Loaded 51100 patterns...
#  → Loaded 51150 patterns...
#  → Loaded 51200 patterns...
#  → Loaded 51250 patterns...
#  → Loaded 51300 patterns...
#  → Loaded 51350 patterns...
#  → Loaded 51400 patterns...
#  → Loaded 51450 patterns...
#  → Loaded 51500 patterns...
#  → Loaded 51550 patterns...
#  → Loaded 51600 patterns...
#  → Loaded 51650 patterns...
#  → Loaded 51700 patterns...
#  → Loaded 51750 patterns...
#  → Loaded 51800 patterns...
#  → Loaded 51850 patterns...
#  → Loaded 51900 patterns...
#  → Loaded 51950 patterns...
#  → Loaded 52000 patterns...
#  → Loaded 52050 patterns...
#  → Loaded 52100 patterns...
#  → Loaded 52150 patterns...
#  → Loaded 52200 patterns...
#  → Loaded 52250 patterns...
#  → Loaded 52300 patterns...
#  → Loaded 52350 patterns...
#  → Loaded 52400 patterns...
#  → Loaded 52450 patterns...
#  → Loaded 52500 patterns...
#  → Loaded 52550 patterns...
#  → Loaded 52600 patterns...
#  → Loaded 52650 patterns...
#  → Loaded 52700 patterns...
#  → Loaded 52750 patterns...
#  → Loaded 52800 patterns...
#  → Loaded 52850 patterns...
#  → Loaded 52900 patterns...
#  → Loaded 52950 patterns...
#  → Loaded 53000 patterns...
#  → Loaded 53050 patterns...
#  → Loaded 53100 patterns...
#  → Loaded 53150 patterns...
#  → Loaded 53200 patterns...
#  → Loaded 53250 patterns...
#  → Loaded 53300 patterns...
#  → Loaded 53350 patterns...
#  → Loaded 53400 patterns...
#  → Loaded 53450 patterns...
#  → Loaded 53500 patterns...
#  → Loaded 53550 patterns...
#  → Loaded 53600 patterns...
#  → Loaded 53650 patterns...
#  → Loaded 53700 patterns...
#  → Loaded 53750 patterns...
#  → Loaded 53800 patterns...
#  → Loaded 53850 patterns...
#  → Loaded 53900 patterns...
#  → Loaded 53950 patterns...
#  → Loaded 54000 patterns...
#  → Loaded 54050 patterns...
#  → Loaded 54100 patterns...
#  → Loaded 54150 patterns...
#  → Loaded 54200 patterns...
#  → Loaded 54250 patterns...
#  → Loaded 54300 patterns...
#  → Loaded 54350 patterns...
#  → Loaded 54400 patterns...
#  → Loaded 54450 patterns...
#  → Loaded 54500 patterns...
#  → Loaded 54550 patterns...
#  → Loaded 54600 patterns...
#  → Loaded 54650 patterns...
#  → Loaded 54700 patterns...
#  → Loaded 54750 patterns...
#  → Loaded 54800 patterns...
#  → Loaded 54850 patterns...
#  → Loaded 54900 patterns...
#  → Loaded 54950 patterns...
#  → Loaded 55000 patterns...
#  → Loaded 55050 patterns...
#  → Loaded 55100 patterns...
#  → Loaded 55150 patterns...
#  → Loaded 55200 patterns...
#  → Loaded 55250 patterns...
#  → Loaded 55300 patterns...
#  → Loaded 55350 patterns...
#  → Loaded 55400 patterns...
#  → Loaded 55450 patterns...
#  → Loaded 55500 patterns...
#  → Loaded 55550 patterns...
#  → Loaded 55600 patterns...
#  → Loaded 55650 patterns...
#  → Loaded 55700 patterns...
#  → Loaded 55750 patterns...
#  → Loaded 55800 patterns...
#  → Loaded 55850 patterns...
#  → Loaded 55900 patterns...
#  → Loaded 55950 patterns...
#  → Loaded 56000 patterns...
#  → Loaded 56050 patterns...
#  → Loaded 56100 patterns...
#  → Loaded 56150 patterns...
#  → Loaded 56200 patterns...
#  → Loaded 56250 patterns...
#  → Loaded 56300 patterns...
#  → Loaded 56350 patterns...
#  → Loaded 56400 patterns...
#  → Loaded 56450 patterns...
#  → Loaded 56500 patterns...
#  → Loaded 56550 patterns...
#  → Loaded 56600 patterns...
#  → Loaded 56650 patterns...
#  → Loaded 56700 patterns...
#  → Loaded 56750 patterns...
#  → Loaded 56800 patterns...
#  → Loaded 56850 patterns...
#  → Loaded 56900 patterns...
#  → Loaded 56950 patterns...
#  → Loaded 57000 patterns...
#  → Loaded 57050 patterns...
#  → Loaded 57100 patterns...
#  → Loaded 57150 patterns...
#  → Loaded 57200 patterns...
#  → Loaded 57250 patterns...
#  → Loaded 57300 patterns...
#  → Loaded 57350 patterns...
#  → Loaded 57400 patterns...
#  → Loaded 57450 patterns...
#  → Loaded 57500 patterns...
#  → Loaded 57550 patterns...
#  → Loaded 57600 patterns...
#  → Loaded 57650 patterns...
#  → Loaded 57700 patterns...
#  → Loaded 57750 patterns...
#  → Loaded 57800 patterns...
#  → Loaded 57850 patterns...
#  → Loaded 57900 patterns...
#  → Loaded 57950 patterns...
#  → Loaded 58000 patterns...
#  → Loaded 58050 patterns...
#  → Loaded 58100 patterns...
#  → Loaded 58150 patterns...
#  → Loaded 58200 patterns...
#  → Loaded 58250 patterns...
#  → Loaded 58300 patterns...
#  → Loaded 58350 patterns...
#  → Loaded 58400 patterns...
#  → Loaded 58450 patterns...
#  → Loaded 58500 patterns...
#  → Loaded 58550 patterns...
#  → Loaded 58600 patterns...
#  → Loaded 58650 patterns...
#  → Loaded 58700 patterns...
#  → Loaded 58750 patterns...
#  → Loaded 58800 patterns...
#  → Loaded 58850 patterns...
#  → Loaded 58900 patterns...
#  → Loaded 58950 patterns...
#  → Loaded 59000 patterns...
#  → Loaded 59050 patterns...
#  → Loaded 59100 patterns...
#  → Loaded 59150 patterns...
#  → Loaded 59200 patterns...
#  → Loaded 59250 patterns...
#  → Loaded 59300 patterns...
#  → Loaded 59350 patterns...
#  → Loaded 59400 patterns...
#  → Loaded 59450 patterns...
#  → Loaded 59500 patterns...
#  → Loaded 59550 patterns...
#  → Loaded 59600 patterns...
#  → Loaded 59650 patterns...
#  → Loaded 59700 patterns...
#  → Loaded 59750 patterns...
#  → Loaded 59800 patterns...
#  → Loaded 59850 patterns...
#  → Loaded 59900 patterns...
#  → Loaded 59950 patterns...
#  → Loaded 60000 patterns...
#  → Loaded 60050 patterns...
#  → Loaded 60100 patterns...
#  → Loaded 60150 patterns...
#  → Loaded 60200 patterns...
#  → Loaded 60250 patterns...
#  → Loaded 60300 patterns...
#  → Loaded 60350 patterns...
#  → Loaded 60400 patterns...
#  → Loaded 60450 patterns...
#  → Loaded 60500 patterns...
#  → Loaded 60550 patterns...
#  → Loaded 60600 patterns...
#  → Loaded 60650 patterns...
#  → Loaded 60700 patterns...
#  → Loaded 60750 patterns...
#  → Loaded 60800 patterns...
#  → Loaded 60850 patterns...
#  → Loaded 60900 patterns...
#  → Loaded 60950 patterns...
#  → Loaded 61000 patterns...
#  → Loaded 61050 patterns...
#  → Loaded 61100 patterns...
#  → Loaded 61150 patterns...
#  → Loaded 61200 patterns...
#  → Loaded 61250 patterns...
#  → Loaded 61300 patterns...
#  → Loaded 61350 patterns...
#  → Loaded 61400 patterns...
#  → Loaded 61450 patterns...
#  → Loaded 61500 patterns...
#  → Loaded 61550 patterns...
#  → Loaded 61600 patterns...
#  → Loaded 61650 patterns...
#  → Loaded 61700 patterns...
#  → Loaded 61750 patterns...
#  → Loaded 61800 patterns...
#  → Loaded 61850 patterns...
#  → Loaded 61900 patterns...
#  → Loaded 61950 patterns...
#  → Loaded 62000 patterns...
#  → Loaded 62050 patterns...
#  → Loaded 62100 patterns...
#  → Loaded 62150 patterns...
#  → Loaded 62200 patterns...
#  → Loaded 62250 patterns...
#  → Loaded 62300 patterns...
#  → Loaded 62350 patterns...
#  → Loaded 62400 patterns...
#  → Loaded 62450 patterns...
#  → Loaded 62500 patterns...
#  → Loaded 62550 patterns...
#  → Loaded 62600 patterns...
#  → Loaded 62650 patterns...
#  → Loaded 62700 patterns...
#  → Loaded 62750 patterns...
#  → Loaded 62800 patterns...
#  → Loaded 62850 patterns...
#  → Loaded 62900 patterns...
#  → Loaded 62950 patterns...
#  → Loaded 63000 patterns...
#  → Loaded 63050 patterns...
#  → Loaded 63100 patterns...
#  → Loaded 63150 patterns...
#  → Loaded 63200 patterns...
#  → Loaded 63250 patterns...
#  → Loaded 63300 patterns...
#  → Loaded 63350 patterns...
#  → Loaded 63400 patterns...
#  → Loaded 63450 patterns...
#  → Loaded 63500 patterns...
#  → Loaded 63550 patterns...
#  → Loaded 63600 patterns...
#  → Loaded 63650 patterns...
#  → Loaded 63700 patterns...
#  → Loaded 63750 patterns...
#  → Loaded 63800 patterns...
#  → Loaded 63850 patterns...
#  → Loaded 63900 patterns...
#  → Loaded 63950 patterns...
#  → Loaded 64000 patterns...
#  → Loaded 64050 patterns...
#  → Loaded 64100 patterns...
#  → Loaded 64150 patterns...
#  → Loaded 64200 patterns...
#  → Loaded 64250 patterns...
#  → Loaded 64300 patterns...
#  → Loaded 64350 patterns...
#  → Loaded 64400 patterns...
#  → Loaded 64450 patterns...
#  → Loaded 64500 patterns...
#  → Loaded 64550 patterns...
#  → Loaded 64600 patterns...
#  → Loaded 64650 patterns...
#  → Loaded 64700 patterns...
#  → Loaded 64750 patterns...
#  → Loaded 64800 patterns...
#  → Loaded 64850 patterns...
#  → Loaded 64900 patterns...
#  → Loaded 64950 patterns...
#  → Loaded 65000 patterns...
#  → Loaded 65050 patterns...
#  → Loaded 65100 patterns...
#  → Loaded 65150 patterns...
#  → Loaded 65200 patterns...
#  → Loaded 65250 patterns...
#  → Loaded 65300 patterns...
#  → Loaded 65350 patterns...
#  → Loaded 65400 patterns...
#  → Loaded 65450 patterns...
#  → Loaded 65500 patterns...
#  → Loaded 65550 patterns...
#  → Loaded 65600 patterns...
#  → Loaded 65650 patterns...
#  → Loaded 65700 patterns...
#  → Loaded 65750 patterns...
#  → Loaded 65800 patterns...
#  → Loaded 65850 patterns...
#  → Loaded 65900 patterns...
#  → Loaded 65950 patterns...
#  → Loaded 66000 patterns...
#  → Loaded 66050 patterns...
#  → Loaded 66100 patterns...
#  → Loaded 66150 patterns...
#  → Loaded 66200 patterns...
#  → Loaded 66250 patterns...
#  → Loaded 66300 patterns...
#  → Loaded 66350 patterns...
#  → Loaded 66400 patterns...
#  → Loaded 66450 patterns...
#  → Loaded 66500 patterns...
#  → Loaded 66550 patterns...
#  → Loaded 66600 patterns...
#  → Loaded 66650 patterns...
#  → Loaded 66700 patterns...
#  → Loaded 66750 patterns...
#  → Loaded 66800 patterns...
#  → Loaded 66850 patterns...
#  → Loaded 66900 patterns...
#  → Loaded 66950 patterns...
#  → Loaded 67000 patterns...
#  → Loaded 67050 patterns...
#  → Loaded 67100 patterns...
#  → Loaded 67150 patterns...
#  → Loaded 67200 patterns...
#  → Loaded 67250 patterns...
#  → Loaded 67300 patterns...
#  → Loaded 67350 patterns...
#  → Loaded 67400 patterns...
#  → Loaded 67450 patterns...
#  → Loaded 67500 patterns...
#  → Loaded 67550 patterns...
#  → Loaded 67600 patterns...
#  → Loaded 67650 patterns...
#  → Loaded 67700 patterns...
#  → Loaded 67750 patterns...
#  → Loaded 67800 patterns...
#  → Loaded 67850 patterns...
#  → Loaded 67900 patterns...
#  → Loaded 67950 patterns...
#  → Loaded 68000 patterns...
#  → Loaded 68050 patterns...
#  → Loaded 68100 patterns...
#  → Loaded 68150 patterns...
#  → Loaded 68200 patterns...
#  → Loaded 68250 patterns...
#  → Loaded 68300 patterns...
#  → Loaded 68350 patterns...
#  → Loaded 68400 patterns...
#  → Loaded 68450 patterns...
#  → Loaded 68500 patterns...
#  → Loaded 68550 patterns...
#  → Loaded 68600 patterns...
#  → Loaded 68650 patterns...
#  → Loaded 68700 patterns...
#  → Loaded 68750 patterns...
#  → Loaded 68800 patterns...
#  → Loaded 68850 patterns...
#  → Loaded 68900 patterns...
#  → Loaded 68950 patterns...
#  → Loaded 69000 patterns...
#  → Loaded 69050 patterns...
#  → Loaded 69100 patterns...
#  → Loaded 69150 patterns...
#  → Loaded 69200 patterns...
#  → Loaded 69250 patterns...
#  → Loaded 69300 patterns...
#  → Loaded 69350 patterns...
#  → Loaded 69400 patterns...
#  → Loaded 69450 patterns...
#  → Loaded 69500 patterns...
#  → Loaded 69550 patterns...
#  → Loaded 69600 patterns...
#  → Loaded 69650 patterns...
#  → Loaded 69700 patterns...
#  → Loaded 69750 patterns...
#  → Loaded 69800 patterns...
#  → Loaded 69850 patterns...
#  → Loaded 69900 patterns...
#  → Loaded 69950 patterns...
#  → Loaded 70000 patterns...
#  → Loaded 70050 patterns...
#  → Loaded 70100 patterns...
#  → Loaded 70150 patterns...
#  → Loaded 70200 patterns...
#  → Loaded 70250 patterns...
#  → Loaded 70300 patterns...
#  → Loaded 70350 patterns...
#  → Loaded 70400 patterns...
#  → Loaded 70450 patterns...
#  → Loaded 70500 patterns...
#  → Loaded 70550 patterns...
#  → Loaded 70600 patterns...
#  → Loaded 70650 patterns...
#  → Loaded 70700 patterns...
#  → Loaded 70750 patterns...
#  → Loaded 70800 patterns...
#  → Loaded 70850 patterns...
#  → Loaded 70900 patterns...
#  → Loaded 70950 patterns...
#  → Loaded 71000 patterns...
#  → Loaded 71050 patterns...
#  → Loaded 71100 patterns...
#  → Loaded 71150 patterns...
#  → Loaded 71200 patterns...
#  → Loaded 71250 patterns...
#  → Loaded 71300 patterns...
#  → Loaded 71350 patterns...
#  → Loaded 71400 patterns...
#  → Loaded 71450 patterns...
#  → Loaded 71500 patterns...
#  → Loaded 71550 patterns...
#  → Loaded 71600 patterns...
#  → Loaded 71650 patterns...
#  → Loaded 71700 patterns...
#  → Loaded 71750 patterns...
#  → Loaded 71800 patterns...
#  → Loaded 71850 patterns...
#  → Loaded 71900 patterns...
#  → Loaded 71950 patterns...
#  → Loaded 72000 patterns...
#  → Loaded 72050 patterns...
#  → Loaded 72100 patterns...
#  → Loaded 72150 patterns...
#  → Loaded 72200 patterns...
#  → Loaded 72250 patterns...
#  → Loaded 72300 patterns...
#  → Loaded 72350 patterns...
#  → Loaded 72400 patterns...
#  → Loaded 72450 patterns...
#  → Loaded 72500 patterns...
#  → Loaded 72550 patterns...
#  → Loaded 72600 patterns...
#  → Loaded 72650 patterns...
#  → Loaded 72700 patterns...
#  → Loaded 72750 patterns...
#  → Loaded 72800 patterns...
#  → Loaded 72850 patterns...
#  → Loaded 72900 patterns...
#  → Loaded 72950 patterns...
#  → Loaded 73000 patterns...
#  → Loaded 73050 patterns...
#  → Loaded 73100 patterns...
#  → Loaded 73150 patterns...
#  → Loaded 73200 patterns...
#  → Loaded 73250 patterns...
#  → Loaded 73300 patterns...
#  → Loaded 73350 patterns...
#  → Loaded 73400 patterns...
#  → Loaded 73450 patterns...
#  → Loaded 73500 patterns...
#  → Loaded 73550 patterns...
#  → Loaded 73600 patterns...
#  → Loaded 73650 patterns...
#  → Loaded 73700 patterns...
#  → Loaded 73750 patterns...
#  → Loaded 73800 patterns...
#  → Loaded 73850 patterns...
#  → Loaded 73900 patterns...
#  → Loaded 73950 patterns...
#  → Loaded 74000 patterns...
#  → Loaded 74050 patterns...
#  → Loaded 74100 patterns...
#  → Loaded 74150 patterns...
#  → Loaded 74200 patterns...
#  → Loaded 74250 patterns...
#  → Loaded 74300 patterns...
#  → Loaded 74350 patterns...
#  → Loaded 74400 patterns...
#  → Loaded 74450 patterns...
#  → Loaded 74500 patterns...
#  → Loaded 74550 patterns...
#  → Loaded 74600 patterns...
#  → Loaded 74650 patterns...
#  → Loaded 74700 patterns...
#  → Loaded 74750 patterns...
#  → Loaded 74800 patterns...
#  → Loaded 74850 patterns...
#  → Loaded 74900 patterns...
#  → Loaded 74950 patterns...
#  → Loaded 75000 patterns...
#  → Loaded 75050 patterns...
#  → Loaded 75100 patterns...
#  → Loaded 75150 patterns...
#  → Loaded 75200 patterns...
#  → Loaded 75250 patterns...
#  → Loaded 75300 patterns...
#  → Loaded 75350 patterns...
#  → Loaded 75400 patterns...
#  → Loaded 75450 patterns...
#  → Loaded 75500 patterns...
#  → Loaded 75550 patterns...
#  → Loaded 75600 patterns...
#  → Loaded 75650 patterns...
#  → Loaded 75700 patterns...
#  → Loaded 75750 patterns...
#  → Loaded 75800 patterns...
#  → Loaded 75850 patterns...
#  → Loaded 75900 patterns...
#  → Loaded 75950 patterns...
#  → Loaded 76000 patterns...
#  → Loaded 76050 patterns...
#  → Loaded 76100 patterns...
#  → Loaded 76150 patterns...
#  → Loaded 76200 patterns...
#  → Loaded 76250 patterns...
#  → Loaded 76300 patterns...
#  → Loaded 76350 patterns...
#  → Loaded 76400 patterns...
#  → Loaded 76450 patterns...
#  → Loaded 76500 patterns...
#  → Loaded 76550 patterns...
#  → Loaded 76600 patterns...
#  → Loaded 76650 patterns...
#  → Loaded 76700 patterns...
#  → Loaded 76750 patterns...
#  → Loaded 76800 patterns...
#  → Loaded 76850 patterns...
#  → Loaded 76900 patterns...
#  → Loaded 76950 patterns...
#  → Loaded 77000 patterns...
#  → Loaded 77050 patterns...
#  → Loaded 77100 patterns...
#  → Loaded 77150 patterns...
#  → Loaded 77200 patterns...
#  → Loaded 77250 patterns...
#  → Loaded 77300 patterns...
#  → Loaded 77350 patterns...
#  → Loaded 77400 patterns...
#  → Loaded 77450 patterns...
#  → Loaded 77500 patterns...
#  → Loaded 77550 patterns...
#  → Loaded 77600 patterns...
#  → Loaded 77650 patterns...
#  → Loaded 77700 patterns...
#  → Loaded 77750 patterns...
#  → Loaded 77800 patterns...
#  → Loaded 77850 patterns...
#  → Loaded 77900 patterns...
#  → Loaded 77950 patterns...
#  → Loaded 78000 patterns...
#  → Loaded 78050 patterns...
#  → Loaded 78100 patterns...
#  → Loaded 78150 patterns...
#  → Loaded 78200 patterns...
#  → Loaded 78250 patterns...
#  → Loaded 78300 patterns...
#  → Loaded 78350 patterns...
#  → Loaded 78400 patterns...
#  → Loaded 78450 patterns...
#  → Loaded 78500 patterns...
#  → Loaded 78550 patterns...
#  → Loaded 78600 patterns...
#  → Loaded 78650 patterns...
#  → Loaded 78700 patterns...
#  → Loaded 78750 patterns...
#  → Loaded 78800 patterns...
#  → Loaded 78850 patterns...
#  → Loaded 78900 patterns...
#  → Loaded 78950 patterns...
#  → Loaded 79000 patterns...
#  → Loaded 79050 patterns...
#  → Loaded 79100 patterns...
#  → Loaded 79150 patterns...
#  → Loaded 79200 patterns...
#  → Loaded 79250 patterns...
#  → Loaded 79300 patterns...
#  → Loaded 79350 patterns...
#  → Loaded 79400 patterns...
#  → Loaded 79450 patterns...
#  → Loaded 79500 patterns...
#  → Loaded 79550 patterns...
#  → Loaded 79600 patterns...
#  → Loaded 79650 patterns...
#  → Loaded 79700 patterns...
#  → Loaded 79750 patterns...
#  → Loaded 79800 patterns...
#  → Loaded 79850 patterns...
#  → Loaded 79900 patterns...
#  → Loaded 79950 patterns...
#  → Loaded 80000 patterns...
#  → Loaded 80050 patterns...
#  → Loaded 80100 patterns...
#  → Loaded 80150 patterns...
#  → Loaded 80200 patterns...
#  → Loaded 80250 patterns...
#  → Loaded 80300 patterns...
#  → Loaded 80350 patterns...
#  → Loaded 80400 patterns...
#  → Loaded 80450 patterns...
#  → Loaded 80500 patterns...
#  → Loaded 80550 patterns...
#  → Loaded 80600 patterns...
#  → Loaded 80650 patterns...
#  → Loaded 80700 patterns...
#  → Loaded 80750 patterns...
#  → Loaded 80800 patterns...
#  → Loaded 80850 patterns...
#  → Loaded 80900 patterns...
#  → Loaded 80950 patterns...
#  → Loaded 81000 patterns...
#  → Loaded 81050 patterns...
#  → Loaded 81100 patterns...
#  → Loaded 81150 patterns...
#  → Loaded 81200 patterns...
#  → Loaded 81250 patterns...
#  → Loaded 81300 patterns...
#  → Loaded 81350 patterns...
#  → Loaded 81400 patterns...
#  → Loaded 81450 patterns...
#  → Loaded 81500 patterns...
#  → Loaded 81550 patterns...
#  → Loaded 81600 patterns...
#  → Loaded 81650 patterns...
#  → Loaded 81700 patterns...
#  → Loaded 81750 patterns...
#  → Loaded 81800 patterns...
#  → Loaded 81850 patterns...
#  → Loaded 81900 patterns...
#  → Loaded 81950 patterns...
#  → Loaded 82000 patterns...
#  → Loaded 82050 patterns...
#  → Loaded 82100 patterns...
#  → Loaded 82150 patterns...
#  → Loaded 82200 patterns...
#  → Loaded 82250 patterns...
#  → Loaded 82300 patterns...
#  → Loaded 82350 patterns...
#  → Loaded 82400 patterns...
#  → Loaded 82450 patterns...
#  → Loaded 82500 patterns...
#  → Loaded 82550 patterns...
#  → Loaded 82600 patterns...
#  → Loaded 82650 patterns...
#  → Loaded 82700 patterns...
#  → Loaded 82750 patterns...
#  → Loaded 82800 patterns...
#  → Loaded 82850 patterns...
#  → Loaded 82900 patterns...
#  → Loaded 82950 patterns...
#  → Loaded 83000 patterns...
#  → Loaded 83050 patterns...
#  → Loaded 83100 patterns...
#  → Loaded 83150 patterns...
#  → Loaded 83200 patterns...
#  → Loaded 83250 patterns...
#  → Loaded 83300 patterns...
#  → Loaded 83350 patterns...
#  → Loaded 83400 patterns...
#  → Loaded 83450 patterns...
#  → Loaded 83500 patterns...
#  → Loaded 83550 patterns...
#  → Loaded 83600 patterns...
#  → Loaded 83650 patterns...
#  → Loaded 83700 patterns...
#  → Loaded 83750 patterns...
#  → Loaded 83800 patterns...
#  → Loaded 83850 patterns...
#  → Loaded 83900 patterns...
#  → Loaded 83950 patterns...
#  → Loaded 84000 patterns...
#  → Loaded 84050 patterns...
#  → Loaded 84100 patterns...
#  → Loaded 84150 patterns...
#  → Loaded 84200 patterns...
#  → Loaded 84250 patterns...
#  → Loaded 84300 patterns...
#  → Loaded 84350 patterns...
#  → Loaded 84400 patterns...
#  → Loaded 84450 patterns...
#  → Loaded 84500 patterns...
#  → Loaded 84550 patterns...
#  → Loaded 84600 patterns...
#  → Loaded 84650 patterns...
#  → Loaded 84700 patterns...
#  → Loaded 84750 patterns...
#  → Loaded 84800 patterns...
#  → Loaded 84850 patterns...
#  → Loaded 84900 patterns...
#  → Loaded 84950 patterns...
#  → Loaded 85000 patterns...
#  → Loaded 85050 patterns...
#  → Loaded 85100 patterns...
#  → Loaded 85150 patterns...
#  → Loaded 85200 patterns...
#  → Loaded 85250 patterns...
#  → Loaded 85300 patterns...
#  → Loaded 85350 patterns...
#  → Loaded 85400 patterns...
#  → Loaded 85450 patterns...
#  → Loaded 85500 patterns...
#  → Loaded 85550 patterns...
#  → Loaded 85600 patterns...
#  → Loaded 85650 patterns...
#  → Loaded 85700 patterns...
#  → Loaded 85750 patterns...
#  → Loaded 85800 patterns...
#  → Loaded 85850 patterns...
#  → Loaded 85900 patterns...
# ...
#  → Loaded 111350 patterns...
#  → Loaded 111400 patterns...
#  → Loaded 111450 patterns...
#  → Loaded 111500 patterns...
#  → Loaded 111550 patterns...
#  → Loaded 111600 patterns...
#  → Loaded 111650 patterns...
#  → Loaded 111700 patterns...
#  → Loaded 111750 patterns...
#  → Loaded 111800 patterns...
#  → Loaded 111850 patterns...
#  → Loaded 111900 patterns...
#  → Loaded 111950 patterns...
#  → Loaded 112000 patterns...
#  → Loaded 112050 patterns...
#  → Loaded 112100 patterns...
#  → Loaded 112150 patterns...
#  → Loaded 112200 patterns...
#  → Loaded 112250 patterns...
#  → Loaded 112300 patterns...
#  → Loaded 112350 patterns...
#  → Loaded 112400 patterns...
#  → Loaded 112450 patterns...
#  → Loaded 112500 patterns...
#  → Loaded 112550 patterns...
#  → Loaded 112600 patterns...
#  → Loaded 112650 patterns...
#  → Loaded 112700 patterns...
#  → Loaded 112750 patterns...
#  → Loaded 112800 patterns...
#  → Loaded 112850 patterns...
#  → Loaded 112900 patterns...
#  → Loaded 112950 patterns...
#  → Loaded 113000 patterns...
#  → Loaded 113050 patterns...
#  → Loaded 113100 patterns...
#  → Loaded 113150 patterns...
#  → Loaded 113200 patterns...
#  → Loaded 113250 patterns...
#  → Loaded 113300 patterns...
#  → Loaded 113350 patterns...
#  → Loaded 113400 patterns...
#  → Loaded 113450 patterns...
#  → Loaded 113500 patterns...
#  → Loaded 113550 patterns...
#  → Loaded 113600 patterns...
#  → Loaded 113650 patterns...
#  → Loaded 113700 patterns...
#  → Loaded 113750 patterns...
#  → Loaded 113800 patterns...
#  → Loaded 113850 patterns...
#  → Loaded 113900 patterns...
#  → Loaded 113950 patterns...
#  → Loaded 114000 patterns...
#  → Loaded 114050 patterns...
#  → Loaded 114100 patterns...
#  → Loaded 114150 patterns...
#  → Loaded 114200 patterns...
#  → Loaded 114250 patterns...
#  → Loaded 114300 patterns...
#  → Loaded 114350 patterns...
#  → Loaded 114400 patterns...
#  → Loaded 114450 patterns...
#  → Loaded 114500 patterns...
#  → Loaded 114550 patterns...
#  → Loaded 114600 patterns...
#  → Loaded 114650 patterns...
#  → Loaded 114700 patterns...
#  → Loaded 114750 patterns...
#  → Loaded 114800 patterns...
#  → Loaded 114850 patterns...
#  → Loaded 114900 patterns...
#  → Loaded 114950 patterns...
#  → Loaded 115000 patterns...
#  → Loaded 115050 patterns...
#  → Loaded 115100 patterns...
#  → Loaded 115150 patterns...
#  → Loaded 115200 patterns...
#  → Loaded 115250 patterns...
#  → Loaded 115300 patterns...
#  → Loaded 115350 patterns...
#  → Loaded 115400 patterns...
#  → Loaded 115450 patterns...
#  → Loaded 115500 patterns...
#  → Loaded 115550 patterns...
#  → Loaded 115600 patterns...
#  → Loaded 115650 patterns...
#  → Loaded 115700 patterns...
#  → Loaded 115750 patterns...
#  → Loaded 115800 patterns...
#  → Loaded 115850 patterns...
#  → Loaded 115900 patterns...
#  → Loaded 115950 patterns...
#  → Loaded 116000 patterns...
#  → Loaded 116050 patterns...
#  → Loaded 116100 patterns...
#  → Loaded 116150 patterns...
#  → Loaded 116200 patterns...
#  → Loaded 116250 patterns...
#  → Loaded 116300 patterns...
#  → Loaded 116350 patterns...
#  → Loaded 116400 patterns...
#  → Loaded 116450 patterns...
#  → Loaded 116500 patterns...
#  → Loaded 116550 patterns...
#  → Loaded 116600 patterns...
#  → Loaded 116650 patterns...
#  → Loaded 116700 patterns...
#  → Loaded 116750 patterns...
#  → Loaded 116800 patterns...
#  → Loaded 116850 patterns...
#  → Loaded 116900 patterns...
#  → Loaded 116950 patterns...
#  → Loaded 117000 patterns...
#  → Loaded 117050 patterns...
#  → Loaded 117100 patterns...
#  → Loaded 117150 patterns...
#  → Loaded 117200 patterns...
#  → Loaded 117250 patterns...
#  → Loaded 117300 patterns...
#  → Loaded 117350 patterns...
#  → Loaded 117400 patterns...
#  → Loaded 117450 patterns...
#  → Loaded 117500 patterns...
#  → Loaded 117550 patterns...
#  → Loaded 117600 patterns...
#  → Loaded 117650 patterns...
#  → Loaded 117700 patterns...
#  → Loaded 117750 patterns...
#  → Loaded 117800 patterns...
#  → Loaded 117850 patterns...
#  → Loaded 117900 patterns...
#  → Loaded 117950 patterns...
#  → Loaded 118000 patterns...
#  → Loaded 118050 patterns...
#  → Loaded 118100 patterns...
#  → Loaded 118150 patterns...
#  → Loaded 118200 patterns...
#  → Loaded 118250 patterns...
#  → Loaded 118300 patterns...
#  → Loaded 118350 patterns...
#  → Loaded 118400 patterns...
#  → Loaded 118450 patterns...
#  → Loaded 118500 patterns...
#  → Loaded 118550 patterns...
#  → Loaded 118600 patterns...
#  → Loaded 118650 patterns...
#  → Loaded 118700 patterns...
#  → Loaded 118750 patterns...
#  → Loaded 118800 patterns...
#  → Loaded 118850 patterns...
#  → Loaded 118900 patterns...
#  → Loaded 118950 patterns...
#  → Loaded 119000 patterns...
#  → Loaded 119050 patterns...
#  → Loaded 119100 patterns...
#  → Loaded 119150 patterns...
#  → Loaded 119200 patterns...
#  → Loaded 119250 patterns...
#  → Loaded 119300 patterns...
#  → Loaded 119350 patterns...
#  → Loaded 119400 patterns...
#  → Loaded 119450 patterns...
#  → Loaded 119500 patterns...
#  → Loaded 119550 patterns...
#  → Loaded 119600 patterns...
#  → Loaded 119650 patterns...
#  → Loaded 119700 patterns...
#  → Loaded 119750 patterns...
#  → Loaded 119800 patterns...
#  → Loaded 119850 patterns...
#  → Loaded 119900 patterns...
#  → Loaded 119950 patterns...
#  → Loaded 120000 patterns...
#  → Loaded 120050 patterns...
#  → Loaded 120100 patterns...
#  → Loaded 120150 patterns...
#  → Loaded 120200 patterns...
#  → Loaded 120250 patterns...
#  → Loaded 120300 patterns...
#  → Loaded 120350 patterns...
#  → Loaded 120400 patterns...
#  → Loaded 120450 patterns...
#  → Loaded 120500 patterns...
#  → Loaded 120550 patterns...
#  → Loaded 120600 patterns...
#  → Loaded 120650 patterns...
#  → Loaded 120700 patterns...
#  → Loaded 120750 patterns...
#  → Loaded 120800 patterns...
#  → Loaded 120850 patterns...
#  → Loaded 120900 patterns...
#  → Loaded 120950 patterns...
#  → Loaded 121000 patterns...
#  → Loaded 121050 patterns...
#  → Loaded 121100 patterns...
#  → Loaded 121150 patterns...
#  → Loaded 121200 patterns...
#  → Loaded 121250 patterns...
#  → Loaded 121300 patterns...
#  → Loaded 121350 patterns...
#  → Loaded 121400 patterns...
#  → Loaded 121450 patterns...
#  → Loaded 121500 patterns...
#  → Loaded 121550 patterns...
#  → Loaded 121600 patterns...
#  → Loaded 121650 patterns...
#  → Loaded 121700 patterns...
#  → Loaded 121750 patterns...
#  → Loaded 121800 patterns...
#  → Loaded 121850 patterns...
#  → Loaded 121900 patterns...
#  → Loaded 121950 patterns...
#  → Loaded 122000 patterns...
#  → Loaded 122050 patterns...
#  → Loaded 122100 patterns...
#  → Loaded 122150 patterns...
#  → Loaded 122200 patterns...
#  → Loaded 122250 patterns...
#  → Loaded 122300 patterns...
#  → Loaded 122350 patterns...
#  → Loaded 122400 patterns...
#  → Loaded 122450 patterns...
#  → Loaded 122500 patterns...
#  → Loaded 122550 patterns...
#  → Loaded 122600 patterns...
#  → Loaded 122650 patterns...
#  → Loaded 122700 patterns...
#  → Loaded 122750 patterns...
#  → Loaded 122800 patterns...
#  → Loaded 122850 patterns...
#  → Loaded 122900 patterns...
#  → Loaded 122950 patterns...
#  → Loaded 123000 patterns...
#  → Loaded 123050 patterns...
#  → Loaded 123100 patterns...
#  → Loaded 123150 patterns...
#  → Loaded 123200 patterns...
#  → Loaded 123250 patterns...
#  → Loaded 123300 patterns...
#  → Loaded 123350 patterns...
#  → Loaded 123400 patterns...
#  → Loaded 123450 patterns...
#  → Loaded 123500 patterns...
#  → Loaded 123550 patterns...
#  → Loaded 123600 patterns...
#  → Loaded 123650 patterns...
#  → Loaded 123700 patterns...
#  → Loaded 123750 patterns...
#  → Loaded 123800 patterns...
#  → Loaded 123850 patterns...
#  → Loaded 123900 patterns...
#  → Loaded 123950 patterns...
#  → Loaded 124000 patterns...
#  → Loaded 124050 patterns...
#  → Loaded 124100 patterns...
#  → Loaded 124150 patterns...
#  → Loaded 124200 patterns...
#  → Loaded 124250 patterns...
#  → Loaded 124300 patterns...
#  → Loaded 124350 patterns...
#  → Loaded 124400 patterns...
#  → Loaded 124450 patterns...
#  → Loaded 124500 patterns...
#  → Loaded 124550 patterns...
#  → Loaded 124600 patterns...
#  → Loaded 124650 patterns...
#  → Loaded 124700 patterns...
#  → Loaded 124750 patterns...
#  → Loaded 124800 patterns...
#  → Loaded 124850 patterns...
#  → Loaded 124900 patterns...
#  → Loaded 124950 patterns...
#  → Loaded 125000 patterns...
#  → Loaded 125050 patterns...
#  → Loaded 125100 patterns...
#  → Loaded 125150 patterns...
#  → Loaded 125200 patterns...
#  → Loaded 125250 patterns...
#  → Loaded 125300 patterns...
#  → Loaded 125350 patterns...
#  → Loaded 125400 patterns...
#  → Loaded 125450 patterns...
#  → Loaded 125500 patterns...
#  → Loaded 125550 patterns...
#  → Loaded 125600 patterns...
#  → Loaded 125650 patterns...
#  → Loaded 125700 patterns...
#  → Loaded 125750 patterns...
#  → Loaded 125800 patterns...
#  → Loaded 125850 patterns...
#  → Loaded 125900 patterns...
#  → Loaded 125950 patterns...
#  → Loaded 126000 patterns...
#  → Loaded 126050 patterns...
#  → Loaded 126100 patterns...
#  → Loaded 126150 patterns...
#  → Loaded 126200 patterns...
#  → Loaded 126250 patterns...
#  → Loaded 126300 patterns...
#  → Loaded 126350 patterns...
#  → Loaded 126400 patterns...
#  → Loaded 126450 patterns...
#  → Loaded 126500 patterns...
#  → Loaded 126550 patterns...
#  → Loaded 126600 patterns...
#  → Loaded 126650 patterns...
#  → Loaded 126700 patterns...
#  → Loaded 126750 patterns...
#  → Loaded 126800 patterns...
#  → Loaded 126850 patterns...
#  → Loaded 126900 patterns...
#  → Loaded 126950 patterns...
#  → Loaded 127000 patterns...
#  → Loaded 127050 patterns...
#  → Loaded 127100 patterns...
#  → Loaded 127150 patterns...
#  → Loaded 127200 patterns...
#  → Loaded 127250 patterns...
#  → Loaded 127300 patterns...
#  → Loaded 127350 patterns...
#  → Loaded 127400 patterns...
#  → Loaded 127450 patterns...
#  → Loaded 127500 patterns...
#  → Loaded 127550 patterns...
#  → Loaded 127600 patterns...
#  → Loaded 127650 patterns...
#  → Loaded 127700 patterns...
#  → Loaded 127750 patterns...
#  → Loaded 127800 patterns...
#  → Loaded 127850 patterns...
#  → Loaded 127900 patterns...
#  → Loaded 127950 patterns...
#  → Loaded 128000 patterns...
#  → Loaded 128050 patterns...
#  → Loaded 128100 patterns...
#  → Loaded 128150 patterns...
#  → Loaded 128200 patterns...
#  → Loaded 128250 patterns...
#  → Loaded 128300 patterns...
#  → Loaded 128350 patterns...
#  → Loaded 128400 patterns...
#  → Loaded 128450 patterns...
#  → Loaded 128500 patterns...
#  → Loaded 128550 patterns...
#  → Loaded 128600 patterns...
#  → Loaded 128650 patterns...
#  → Loaded 128700 patterns...
#  → Loaded 128750 patterns...
#  → Loaded 128800 patterns...
#  → Loaded 128850 patterns...
#  → Loaded 128900 patterns...
#  → Loaded 128950 patterns...
#  → Loaded 129000 patterns...
#  → Loaded 129050 patterns...
#  → Loaded 129100 patterns...
#  → Loaded 129150 patterns...
#  → Loaded 129200 patterns...
#  → Loaded 129250 patterns...
#  → Loaded 129300 patterns...
#  → Loaded 129350 patterns...
#  → Loaded 129400 patterns...
#  → Loaded 129450 patterns...
#  → Loaded 129500 patterns...
#  → Loaded 129550 patterns...
#  → Loaded 129600 patterns...
#  → Loaded 129650 patterns...
#  → Loaded 129700 patterns...
#  → Loaded 129750 patterns...
#  → Loaded 129800 patterns...
#  → Loaded 129850 patterns...
#  → Loaded 129900 patterns...
#  → Loaded 129950 patterns...
#  → Loaded 130000 patterns...
#  → Loaded 130050 patterns...
#  → Loaded 130100 patterns...
#  → Loaded 130150 patterns...
#  → Loaded 130200 patterns...
#  → Loaded 130250 patterns...
#  → Loaded 130300 patterns...
#  → Loaded 130350 patterns...
#  → Loaded 130400 patterns...
#  → Loaded 130450 patterns...
#  → Loaded 130500 patterns...
#  → Loaded 130550 patterns...
#  → Loaded 130600 patterns...
#  → Loaded 130650 patterns...
#  → Loaded 130700 patterns...
#  → Loaded 130750 patterns...
#  → Loaded 130800 patterns...
#  → Loaded 130850 patterns...
#  → Loaded 130900 patterns...
#  → Loaded 130950 patterns...
#  → Loaded 131000 patterns...
#  → Loaded 131050 patterns...
#  → Loaded 131100 patterns...
#  → Loaded 131150 patterns...
#  → Loaded 131200 patterns...
#  → Loaded 131250 patterns...
#  → Loaded 131300 patterns...
#  → Loaded 131350 patterns...
#  → Loaded 131400 patterns...
#  → Loaded 131450 patterns...
#  → Loaded 131500 patterns...
#  → Loaded 131550 patterns...
#  → Loaded 131600 patterns...
#  → Loaded 131650 patterns...
#  → Loaded 131700 patterns...
#  → Loaded 131750 patterns...
#  → Loaded 131800 patterns...
#  → Loaded 131850 patterns...
#  → Loaded 131900 patterns...
#  → Loaded 131950 patterns...
#  → Loaded 132000 patterns...
#  → Loaded 132050 patterns...
#  → Loaded 132100 patterns...
#  → Loaded 132150 patterns...
#  → Loaded 132200 patterns...
#  → Loaded 132250 patterns...
#  → Loaded 132300 patterns...
#  → Loaded 132350 patterns...
#  → Loaded 132400 patterns...
#  → Loaded 132450 patterns...
#  → Loaded 132500 patterns...
#  → Loaded 132550 patterns...
#  → Loaded 132600 patterns...
#  → Loaded 132650 patterns...
#  → Loaded 132700 patterns...
#  → Loaded 132750 patterns...
#  → Loaded 132800 patterns...
#  → Loaded 132850 patterns...
#  → Loaded 132900 patterns...
#  → Loaded 132950 patterns...
#  → Loaded 133000 patterns...
#  → Loaded 133050 patterns...
#  → Loaded 133100 patterns...
#  → Loaded 133150 patterns...
#  → Loaded 133200 patterns...
#  → Loaded 133250 patterns...
#  → Loaded 133300 patterns...
#  → Loaded 133350 patterns...
#  → Loaded 133400 patterns...
#  → Loaded 133450 patterns...
#  → Loaded 133500 patterns...
#  → Loaded 133550 patterns...
#  → Loaded 133600 patterns...
#  → Loaded 133650 patterns...
#  → Loaded 133700 patterns...
#  → Loaded 133750 patterns...
#  → Loaded 133800 patterns...
#  → Loaded 133850 patterns...
#  → Loaded 133900 patterns...
#  → Loaded 133950 patterns...
#  → Loaded 134000 patterns...
#  → Loaded 134050 patterns...
#  → Loaded 134100 patterns...
#  → Loaded 134150 patterns...
#  → Loaded 134200 patterns...
#  → Loaded 134250 patterns...
#  → Loaded 134300 patterns...
#  → Loaded 134350 patterns...
#  → Loaded 134400 patterns...
#  → Loaded 134450 patterns...
#  → Loaded 134500 patterns...
#  → Loaded 134550 patterns...
#  → Loaded 134600 patterns...
#  → Loaded 134650 patterns...
#  → Loaded 134700 patterns...
#  → Loaded 134750 patterns...
#  → Loaded 134800 patterns...
#  → Loaded 134850 patterns...
#  → Loaded 134900 patterns...
#  → Loaded 134950 patterns...
#  → Loaded 135000 patterns...
#  → Loaded 135050 patterns...
#  → Loaded 135100 patterns...
#  → Loaded 135150 patterns...
#  → Loaded 135200 patterns...
#  → Loaded 135250 patterns...
#  → Loaded 135300 patterns...
#  → Loaded 135350 patterns...
#  → Loaded 135400 patterns...
#  → Loaded 135450 patterns...
#  → Loaded 135500 patterns...
#  → Loaded 135550 patterns...
#  → Loaded 135600 patterns...
#  → Loaded 135650 patterns...
#  → Loaded 135700 patterns...
#  → Loaded 135750 patterns...
#  → Loaded 135800 patterns...
#  → Loaded 135850 patterns...
#  → Loaded 135900 patterns...
#  → Loaded 135950 patterns...
#  → Loaded 136000 patterns...
#  → Loaded 136050 patterns...
#  → Loaded 136100 patterns...
#  → Loaded 136150 patterns...
#  → Loaded 136200 patterns...
#  → Loaded 136250 patterns...
#  → Loaded 136300 patterns...
#  → Loaded 136350 patterns...
#  → Loaded 136400 patterns...
#  → Loaded 136450 patterns...
#  → Loaded 136500 patterns...
#  → Loaded 136550 patterns...
#  → Loaded 136600 patterns...
#  → Loaded 136650 patterns...
#  → Loaded 136700 patterns...
#  → Loaded 136750 patterns...
#  → Loaded 136800 patterns...
#  → Loaded 136850 patterns...
#  → Loaded 136900 patterns...
#  → Loaded 136950 patterns...
#  → Loaded 137000 patterns...
#  → Loaded 137050 patterns...
#  → Loaded 137100 patterns...
#  → Loaded 137150 patterns...
#  → Loaded 137200 patterns...
#  → Loaded 137250 patterns...
#  → Loaded 137300 patterns...
#  → Loaded 137350 patterns...
#  → Loaded 137400 patterns...
#  → Loaded 137450 patterns...
#  → Loaded 137500 patterns...
#  → Loaded 137550 patterns...
#  → Loaded 137600 patterns...
#  → Loaded 137650 patterns...
#  → Loaded 137700 patterns...
#  → Loaded 137750 patterns...
#  → Loaded 137800 patterns...
#  → Loaded 137850 patterns...
#  → Loaded 137900 patterns...
#  → Loaded 137950 patterns...
#  → Loaded 138000 patterns...
#  → Loaded 138050 patterns...
#  → Loaded 138100 patterns...
#  → Loaded 138150 patterns...
#  → Loaded 138200 patterns...
#  → Loaded 138250 patterns...
#  → Loaded 138300 patterns...
#  → Loaded 138350 patterns...
#  → Loaded 138400 patterns...
#  → Loaded 138450 patterns...
#  → Loaded 138500 patterns...
#  → Loaded 138550 patterns...
#  → Loaded 138600 patterns...
#  → Loaded 138650 patterns...
#  → Loaded 138700 patterns...
#  → Loaded 138750 patterns...
# Done! Total patterns: 138773
# Saved HDF5 → S3A_Grid6_Step4_merged_aztec.h5
